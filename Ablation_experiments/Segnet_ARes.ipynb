# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from datetime import datetime 
import cv2
from PIL import Image
from keras import backend, optimizers
import glob
from sklearn.model_selection import train_test_split
# Out:
# 2023-03-20 21:22:22.304118: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 21:22:22.513452: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-20 21:22:23.258696: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-03-20 21:22:23.258797: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-03-20 21:22:23.258809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# !git clone https://github.com/Shankar0x/Datasets.git imgs
from PIL import Image
# Out:
# fatal: destination path 'imgs' already exists and is not an empty directory.

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts


filelist_trainx = sorted(glob.glob('imgs/Resized_Skin_Lesion_Dataset/Train_images/Trainx/*.bmp'), key=numericalSort)
x_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('imgs/Resized_Skin_Lesion_Dataset/Train_masks/Trainy/*.bmp'), key=numericalSort)
y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# filelist_trainx = sorted(glob.glob('imgs/Electron_Microscopy_Dataset/images/*.tif'), key=numericalSort)
# x_train = np.array([np.array(Image.open(fname).convert('RGB')) for fname in filelist_trainx])

# filelist_trainy = sorted(glob.glob('imgs/Electron_Microscopy_Dataset/masks/*.tif'), key=numericalSort)
# y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# filelist_trainx = sorted(glob.glob('imgs/Skin_Lesion_Dataset/trainx/*.jpg'), key=numericalSort)
# x_train = np.array([np.array(Image.open(fname).convert('RGB')) for fname in filelist_trainx])

# filelist_trainy = sorted(glob.glob('imgs/Skin_Lesion_Dataset/trainy/*.jpg'), key=numericalSort)
# y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])


print("X_train shape: ",x_train.shape)
print("Y_train shape: ",y_train.shape)
plt.subplot(1,2,1)
plt.imshow(x_train[0].astype('uint8'))
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(y_train[0].astype('uint8'),cmap = plt.cm.binary_r)
plt.axis('off')
plt.show()
# Out:
# X_train shape:  (200, 192, 256, 3)
# Y_train shape:  (200, 192, 256)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.25,random_state=101)

# %%
print("X_train shape: ",x_train.shape)
print("Y_train shape: ",y_train.shape)
print("X_test shape: ",x_test.shape)
print("Y_test shape: ",y_test.shape)
# Out:
# X_train shape:  (150, 192, 256, 3)
# Y_train shape:  (150, 192, 256)
# X_test shape:  (50, 192, 256, 3)
# Y_test shape:  (50, 192, 256)

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
y_train_full.shape
# Out:
# (450, 192, 256)

# %%
# expanding dimensions of the masks
y_train_full_exp = np.zeros((y_train_full.shape[0], y_train_full.shape[1], y_train_full.shape[2],1))
for i in range(y_train_full.shape[0]):
    y_train_full_exp[i] = np.expand_dims(y_train_full[i], 2)

y_test_exp = np.zeros((y_test.shape[0], y_test.shape[1], y_test.shape[2], 1))
for i in range(y_test.shape[0]):
    y_test_exp[i] = np.expand_dims(y_test[i],2)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full_exp, test_size = 0.20, random_state = 101)

# %%
y_test = y_test_exp
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test_exp.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (360, 192, 256, 3)
# (360, 192, 256, 1)
# (50, 192, 256, 3)
# (50, 192, 256, 1)
# (90, 192, 256, 3)
# (90, 192, 256, 1)

# %% [markdown]
# ### Old code

# %%
# image_directory = 'imgs/Resized_Skin_Lesion_Dataset/Train_images/Trainx/'
# mask_directory = 'imgs/Resized_Skin_Lesion_Dataset/Train_masks/Trainy/'

# %%
# SIZE = 256
# image_dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
# mask_dataset = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

# images = os.listdir(image_directory)
# for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
#     if (image_name.split('.')[1] == 'bmp'):
#         #print(image_directory+image_name)
#         image = cv2.imread(image_directory+image_name, 1)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB )
#         image = Image.fromarray(image)
#         image = image.resize((SIZE, SIZE))
#         image_dataset.append(np.array(image))

# %%
# masks = os.listdir(mask_directory)
# for i, image_name in enumerate(masks):
#     if (image_name.split('.')[1] == 'bmp'):
#         image = cv2.imread(mask_directory+image_name, 0)
#         image = Image.fromarray(image)
#         image = image.resize((SIZE, SIZE))
#         mask_dataset.append(np.array(image))

# %%
# #Normalize images
# image_dataset = np.array(image_dataset)/255.
# #D not normalize masks, just rescale to 0 to 1.
# mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

# %%
# X_train.shape

# %%
# y_train.shape

# %%
# import random
# import numpy as np
# image_number = random.randint(0, len(X_train))
# plt.figure(figsize=(12, 6))
# plt.subplot(121)
# plt.imshow(np.reshape(X_train[image_number], (256, 256, 3)))
# plt.subplot(122)
# plt.imshow(np.reshape(y_train[image_number], (256, 256)), cmap='gray')
# plt.show()

# %%
IMG_HEIGHT = x_train.shape[1]
IMG_WIDTH  = x_train.shape[2]
IMG_CHANNELS = x_train.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8

#FOCAL LOSS AND DICE METRIC
#Focal loss helps focus more on tough to segment classes.
from focal_loss import BinaryFocalLoss

# %%
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K
from keras.models import Model

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape 
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block_2(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def res_conv_block_3(x, filter_size, size, dropout, batch_norm=False):
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def Attention_ResSegNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    # input data
    # dimension of the image depth
    inputs = layers.Input(input_shape, dtype=tf.float32)
    
    axis = 3

    # Downsampling layers
    # DownRes 1, double residual convolution + pooling
    conv_64 = res_conv_block_2(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 2
    conv_128 = res_conv_block_2(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_128 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 3
    conv_256 = res_conv_block_3(pool_128, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_256 = layers.MaxPooling2D(pool_size=(2,2))(conv_256)
    # DownRes 4
    conv_512_1 = res_conv_block_3(pool_256, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_512_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_512_1)
    # DownRes 5
    conv_512_2 = res_conv_block_3(pool_512_1, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_512_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_512_2)
    # DownRes 6, convolution only
    bridge = res_conv_block_2(pool_512_2, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 7, attention gated concatenation + upsampling + double residual convolution
    gating_512_2 = gating_signal(bridge, 8*FILTER_NUM, batch_norm)
    att_512_2 = attention_block(conv_512_2, gating_512_2, 8*FILTER_NUM)
    up_512_2 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(bridge)
    up_512_2 = layers.concatenate([up_512_2, att_512_2], axis=axis)
    up_conv_512_2 = res_conv_block_3(up_512_2, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_512_1 = gating_signal(up_conv_512_2, 8*FILTER_NUM, batch_norm)
    att_512_1 = attention_block(conv_512_1, gating_512_1, 8*FILTER_NUM)
    up_512_1 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_512_2)
    up_512_1 = layers.concatenate([up_512_1, att_512_1], axis=axis)
    up_conv_512_1 = res_conv_block_3(up_512_1, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_256 = gating_signal(up_conv_512_1, 4*FILTER_NUM, batch_norm)
    att_256 = attention_block(conv_256, gating_256, 4*FILTER_NUM)
    up_256 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_512_1)
    up_256 = layers.concatenate([up_256, att_256], axis=axis)
    up_conv_256 = res_conv_block_3(up_256, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 10
    gating_128 = gating_signal(up_conv_256, 2*FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, 2*FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_256)
    up_128 = layers.concatenate([up_128, att_128], axis=axis)
    up_conv_128 = res_conv_block_2(up_128, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_64 = gating_signal(up_conv_128, FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_128)
    up_64 = layers.concatenate([up_64, att_64], axis=axis)
    up_conv_64 = res_conv_block_2(up_64, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_64)
    conv_final = layers.BatchNormalization(axis=axis)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs, conv_final, name="AttentionResUNet")
    return model, inputs, att_512_2, att_512_1, att_256, att_128, att_64, conv_64, conv_128, conv_256, conv_512_1, conv_512_2, up_conv_512_2, up_conv_512_1, up_conv_256, up_conv_128, up_conv_64

# %%
att_res_SegNet_model, input_inter, att_512_2, att_512_1, att_256, att_128, att_64, conv_64, conv_128, conv_256, conv_512_1, conv_512_2, up_conv_512_2, up_conv_512_1, up_conv_256, up_conv_128, up_conv_64 = Attention_ResSegNet(input_shape)

att_res_SegNet_model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coef])

print(att_res_SegNet_model.summary())


start3 = datetime.now() 
att_res_SegNet_history = att_res_SegNet_model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=100)
stop3 = datetime.now()

#Execution time of the model 
execution_time_AttResSegNet = stop3-start3
print("Attention ResSegNet execution time is: ", execution_time_AttResSegNet)

att_res_SegNet_model.save('skin_AttResSegNet_150epochs_B_focal.hdf5')
# Out:
# 2023-03-20 21:22:33.602337: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 21:22:34.466703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14625 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 192, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 192, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 192, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 192, 256, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 192, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 192, 256, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_1 (BatchNo  (None, 192, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 192, 256, 64  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  activation_1 (Activation)      (None, 192, 256, 64  0           ['add[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 96, 128, 64)  0           ['activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 96, 128, 128  73856       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 96, 128, 128  512        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 96, 128, 128  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 96, 128, 128  8320        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 96, 128, 128  147584      ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 96, 128, 128  512        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_4 (BatchNo  (None, 96, 128, 128  512        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 96, 128, 128  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 96, 128, 128  0           ['add_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 48, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 48, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 48, 64, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 48, 64, 256)  33024       ['max_pooling2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 48, 64, 256)  590080      ['activation_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 48, 64, 256)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_6 (Activation)      (None, 48, 64, 256)  0           ['add_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 24, 32, 256)  0          ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 24, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 24, 32, 512)  2359808     ['activation_7[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 24, 32, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 24, 32, 512)  131584      ['max_pooling2d_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 32, 512)  2359808     ['activation_8[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 24, 32, 512)  0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_9 (Activation)      (None, 24, 32, 512)  0           ['add_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 16, 512)  0          ['activation_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 16, 512)  2359808     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 12, 16, 512)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 16, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 12, 16, 512)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 16, 512)  262656      ['max_pooling2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 16, 512)  2359808     ['activation_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 12, 16, 512)  0           ['batch_normalization_17[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_12 (Activation)     (None, 12, 16, 512)  0           ['add_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 6, 8, 512)   0           ['activation_12[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 6, 8, 1024)   4719616     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 6, 8, 1024)  4096        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 6, 8, 1024)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 6, 8, 1024)   525312      ['max_pooling2d_4[0][0]']
#  conv2d_19 (Conv2D)             (None, 6, 8, 1024)   9438208     ['activation_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 6, 8, 1024)  4096        ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 6, 8, 1024)  4096        ['conv2d_19[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 6, 8, 1024)   0           ['batch_normalization_20[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  activation_14 (Activation)     (None, 6, 8, 1024)   0           ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 6, 8, 512)    524800      ['activation_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 6, 8, 512)   2048        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 6, 8, 512)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 6, 8, 512)    262656      ['activation_15[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 6, 8, 512)   2359808     ['conv2d_23[0][0]']
#  ose)
#
#  conv2d_22 (Conv2D)             (None, 6, 8, 512)    1049088     ['activation_12[0][0]']
#
#  add_6 (Add)                    (None, 6, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  activation_16 (Activation)     (None, 6, 8, 512)    0           ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 8, 1)      513         ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 6, 8, 1)      0           ['conv2d_24[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 12, 16, 1)    0           ['activation_17[0][0]']
#
#  lambda (Lambda)                (None, 12, 16, 512)  0           ['up_sampling2d[0][0]']
#
#  multiply (Multiply)            (None, 12, 16, 512)  0           ['lambda[0][0]',
#                                                                   'activation_12[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 16, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 12, 16, 1024  0          ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 12, 16, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 16, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 12, 16, 512)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 12, 16, 512)  2359808     ['activation_18[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 12, 16, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 16, 512)  786944      ['concatenate[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 12, 16, 512)  2359808     ['activation_19[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 12, 16, 512)  0           ['batch_normalization_26[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  activation_20 (Activation)     (None, 12, 16, 512)  0           ['add_7[0][0]']
#  conv2d_30 (Conv2D)             (None, 12, 16, 512)  262656      ['activation_20[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 12, 16, 512)  2048       ['conv2d_30[0][0]']
# /home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  ormalization)
#
#  activation_21 (Activation)     (None, 12, 16, 512)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 16, 512)  262656      ['activation_21[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 12, 16, 512)  2359808    ['conv2d_32[0][0]']
#  spose)
#
#  conv2d_31 (Conv2D)             (None, 12, 16, 512)  1049088     ['activation_9[0][0]']
#
#  add_8 (Add)                    (None, 12, 16, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  activation_22 (Activation)     (None, 12, 16, 512)  0           ['add_8[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 16, 1)    513         ['activation_22[0][0]']
#
#  activation_23 (Activation)     (None, 12, 16, 1)    0           ['conv2d_33[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 24, 32, 1)   0           ['activation_23[0][0]']
#
#  lambda_1 (Lambda)              (None, 24, 32, 512)  0           ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 24, 32, 512)  0           ['lambda_1[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 24, 32, 512)  262656      ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 24, 32, 512)  0          ['activation_20[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 24, 32, 1024  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'batch_normalization_28[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 24, 32, 512)  4719104     ['concatenate_1[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 24, 32, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 24, 32, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 24, 32, 512)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 24, 32, 512)  524800      ['concatenate_1[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 24, 32, 512)  2359808     ['activation_25[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 24, 32, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 24, 32, 512)  0           ['batch_normalization_32[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_26 (Activation)     (None, 24, 32, 512)  0           ['add_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 24, 32, 256)  131328      ['activation_26[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 24, 32, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 24, 32, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 24, 32, 256)  65792       ['activation_27[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 24, 32, 256)  590080     ['conv2d_41[0][0]']
#  spose)
#
#  conv2d_40 (Conv2D)             (None, 24, 32, 256)  262400      ['activation_6[0][0]']
#
#  add_10 (Add)                   (None, 24, 32, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_40[0][0]']
#  activation_28 (Activation)     (None, 24, 32, 256)  0           ['add_10[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 24, 32, 1)    257         ['activation_28[0][0]']
#
#  activation_29 (Activation)     (None, 24, 32, 1)    0           ['conv2d_42[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 48, 64, 1)   0           ['activation_29[0][0]']
#
#  lambda_2 (Lambda)              (None, 48, 64, 256)  0           ['up_sampling2d_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 48, 64, 256)  0           ['lambda_2[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 48, 64, 256)  65792       ['multiply_2[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 48, 64, 512)  0          ['activation_26[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 48, 64, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 48, 64, 768)  0           ['up_sampling2d_5[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 48, 64, 256)  1769728     ['concatenate_2[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 48, 64, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 48, 64, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 48, 64, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 48, 64, 256)  1024       ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 48, 64, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 48, 64, 256)  196864      ['concatenate_2[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 48, 64, 256)  590080      ['activation_31[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 48, 64, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 48, 64, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 48, 64, 256)  0           ['batch_normalization_38[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_32 (Activation)     (None, 48, 64, 256)  0           ['add_11[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 48, 64, 128)  32896       ['activation_32[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 48, 64, 128)  512        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 48, 64, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 48, 64, 128)  16512       ['activation_33[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 48, 64, 128)  147584     ['conv2d_50[0][0]']
#  spose)
#
#  conv2d_49 (Conv2D)             (None, 48, 64, 128)  65664       ['activation_3[0][0]']
#
#  add_12 (Add)                   (None, 48, 64, 128)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  activation_34 (Activation)     (None, 48, 64, 128)  0           ['add_12[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 48, 64, 1)    129         ['activation_34[0][0]']
#
#  activation_35 (Activation)     (None, 48, 64, 1)    0           ['conv2d_51[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 96, 128, 1)  0           ['activation_35[0][0]']
#
#  lambda_3 (Lambda)              (None, 96, 128, 128  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 96, 128, 128  0           ['lambda_3[0][0]',
#                                 )                                 'activation_3[0][0]']
#  conv2d_52 (Conv2D)             (None, 96, 128, 128  16512       ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 96, 128, 256  0          ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 96, 128, 128  512        ['conv2d_52[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 96, 128, 384  0           ['up_sampling2d_7[0][0]',
#                                 )                                 'batch_normalization_40[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 96, 128, 128  442496      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 96, 128, 128  512        ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 96, 128, 128  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 96, 128, 128  49280       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 96, 128, 128  147584      ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 96, 128, 128  512        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  batch_normalization_42 (BatchN  (None, 96, 128, 128  512        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  add_13 (Add)                   (None, 96, 128, 128  0           ['batch_normalization_43[0][0]',
#                                 )                                 'batch_normalization_42[0][0]']
#
#  activation_37 (Activation)     (None, 96, 128, 128  0           ['add_13[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 96, 128, 64)  8256        ['activation_37[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 96, 128, 64)  256        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 96, 128, 64)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 96, 128, 64)  4160        ['activation_38[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 96, 128, 64)  36928      ['conv2d_58[0][0]']
#  spose)
#
#  conv2d_57 (Conv2D)             (None, 96, 128, 64)  16448       ['activation_1[0][0]']
#
#  add_14 (Add)                   (None, 96, 128, 64)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  activation_39 (Activation)     (None, 96, 128, 64)  0           ['add_14[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 96, 128, 1)   65          ['activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 96, 128, 1)   0           ['conv2d_59[0][0]']
#
# ...
# Epoch 19/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.0319 - accuracy: 0.9534 - jacard_coef: 0.5766 - val_loss: 0.0435 - val_accuracy: 0.9456 - val_jacard_coef: 0.5359
# Epoch 20/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0303 - accuracy: 0.9556 - jacard_coef: 0.5889 - val_loss: 0.0356 - val_accuracy: 0.9484 - val_jacard_coef: 0.5375
# Epoch 21/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0286 - accuracy: 0.9577 - jacard_coef: 0.6010 - val_loss: 0.0411 - val_accuracy: 0.9452 - val_jacard_coef: 0.5377
# Epoch 22/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0305 - accuracy: 0.9556 - jacard_coef: 0.5960 - val_loss: 0.0491 - val_accuracy: 0.9416 - val_jacard_coef: 0.5696
# Epoch 23/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0282 - accuracy: 0.9584 - jacard_coef: 0.6092 - val_loss: 0.0429 - val_accuracy: 0.9475 - val_jacard_coef: 0.5717
# Epoch 24/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0267 - accuracy: 0.9614 - jacard_coef: 0.6176 - val_loss: 0.0439 - val_accuracy: 0.9419 - val_jacard_coef: 0.5194
# Epoch 25/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0241 - accuracy: 0.9653 - jacard_coef: 0.6267 - val_loss: 0.0353 - val_accuracy: 0.9512 - val_jacard_coef: 0.5288
# Epoch 26/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0239 - accuracy: 0.9656 - jacard_coef: 0.6347 - val_loss: 0.0551 - val_accuracy: 0.9444 - val_jacard_coef: 0.5244
# Epoch 27/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0238 - accuracy: 0.9649 - jacard_coef: 0.6418 - val_loss: 0.0413 - val_accuracy: 0.9461 - val_jacard_coef: 0.5563
# Epoch 28/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0209 - accuracy: 0.9701 - jacard_coef: 0.6539 - val_loss: 0.0416 - val_accuracy: 0.9409 - val_jacard_coef: 0.5213
# Epoch 29/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0219 - accuracy: 0.9685 - jacard_coef: 0.6552 - val_loss: 0.0573 - val_accuracy: 0.9509 - val_jacard_coef: 0.5770
# Epoch 30/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0255 - accuracy: 0.9628 - jacard_coef: 0.6403 - val_loss: 0.1125 - val_accuracy: 0.9004 - val_jacard_coef: 0.5503
# Epoch 31/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0276 - accuracy: 0.9590 - jacard_coef: 0.6291 - val_loss: 0.2386 - val_accuracy: 0.8499 - val_jacard_coef: 0.5202
# Epoch 32/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0224 - accuracy: 0.9674 - jacard_coef: 0.6568 - val_loss: 0.0527 - val_accuracy: 0.9330 - val_jacard_coef: 0.5482
# Epoch 33/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0210 - accuracy: 0.9693 - jacard_coef: 0.6647 - val_loss: 0.1014 - val_accuracy: 0.9358 - val_jacard_coef: 0.5633
# Epoch 34/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0215 - accuracy: 0.9680 - jacard_coef: 0.6682 - val_loss: 0.1179 - val_accuracy: 0.9372 - val_jacard_coef: 0.5858
# Epoch 35/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0273 - accuracy: 0.9617 - jacard_coef: 0.6540 - val_loss: 0.3299 - val_accuracy: 0.8892 - val_jacard_coef: 0.5538
# Epoch 36/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0338 - accuracy: 0.9509 - jacard_coef: 0.6101 - val_loss: 0.2328 - val_accuracy: 0.8300 - val_jacard_coef: 0.4847
# Epoch 37/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0428 - accuracy: 0.9378 - jacard_coef: 0.5823 - val_loss: 2.2668 - val_accuracy: 0.5555 - val_jacard_coef: 0.3827
# Epoch 38/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0256 - accuracy: 0.9628 - jacard_coef: 0.6287 - val_loss: 0.0843 - val_accuracy: 0.9267 - val_jacard_coef: 0.6395
# Epoch 39/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0216 - accuracy: 0.9687 - jacard_coef: 0.6551 - val_loss: 0.0391 - val_accuracy: 0.9469 - val_jacard_coef: 0.5965
# Epoch 40/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0205 - accuracy: 0.9696 - jacard_coef: 0.6713 - val_loss: 0.0321 - val_accuracy: 0.9553 - val_jacard_coef: 0.5587
# Epoch 41/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0185 - accuracy: 0.9724 - jacard_coef: 0.6796 - val_loss: 0.0409 - val_accuracy: 0.9489 - val_jacard_coef: 0.5865
# Epoch 42/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0176 - accuracy: 0.9738 - jacard_coef: 0.6922 - val_loss: 0.0402 - val_accuracy: 0.9477 - val_jacard_coef: 0.6085
# Epoch 43/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0169 - accuracy: 0.9750 - jacard_coef: 0.6973 - val_loss: 0.0430 - val_accuracy: 0.9493 - val_jacard_coef: 0.6075
# Epoch 44/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0186 - accuracy: 0.9719 - jacard_coef: 0.6886 - val_loss: 0.0539 - val_accuracy: 0.9384 - val_jacard_coef: 0.6116
# Epoch 45/100
# 45/45 [==============================] - 10s 222ms/step - loss: 0.0173 - accuracy: 0.9743 - jacard_coef: 0.7016 - val_loss: 0.1149 - val_accuracy: 0.9202 - val_jacard_coef: 0.6177
# Epoch 46/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0204 - accuracy: 0.9701 - jacard_coef: 0.6812 - val_loss: 0.0859 - val_accuracy: 0.9494 - val_jacard_coef: 0.6803
# Epoch 47/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0177 - accuracy: 0.9736 - jacard_coef: 0.6937 - val_loss: 0.0510 - val_accuracy: 0.9491 - val_jacard_coef: 0.6514
# Epoch 48/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0161 - accuracy: 0.9759 - jacard_coef: 0.7080 - val_loss: 0.0490 - val_accuracy: 0.9528 - val_jacard_coef: 0.6628
# Epoch 49/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0156 - accuracy: 0.9764 - jacard_coef: 0.7133 - val_loss: 0.0759 - val_accuracy: 0.9466 - val_jacard_coef: 0.6546
# Epoch 50/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0163 - accuracy: 0.9757 - jacard_coef: 0.7161 - val_loss: 0.0888 - val_accuracy: 0.9427 - val_jacard_coef: 0.6947
# Epoch 51/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0165 - accuracy: 0.9751 - jacard_coef: 0.7132 - val_loss: 0.1091 - val_accuracy: 0.9469 - val_jacard_coef: 0.6959
# Epoch 52/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0178 - accuracy: 0.9734 - jacard_coef: 0.7035 - val_loss: 0.4019 - val_accuracy: 0.8862 - val_jacard_coef: 0.6035
# Epoch 53/100
# 45/45 [==============================] - 10s 221ms/step - loss: 0.0197 - accuracy: 0.9705 - jacard_coef: 0.6926 - val_loss: 0.1096 - val_accuracy: 0.9460 - val_jacard_coef: 0.6710
# Epoch 54/100
# 45/45 [==============================] - 10s 222ms/step - loss: 0.0159 - accuracy: 0.9761 - jacard_coef: 0.7132 - val_loss: 0.0981 - val_accuracy: 0.9393 - val_jacard_coef: 0.6356
# Epoch 55/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.0145 - accuracy: 0.9781 - jacard_coef: 0.7316 - val_loss: 0.1194 - val_accuracy: 0.9288 - val_jacard_coef: 0.6464
# Epoch 56/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0142 - accuracy: 0.9781 - jacard_coef: 0.7353 - val_loss: 0.1184 - val_accuracy: 0.9431 - val_jacard_coef: 0.6642
# Epoch 57/100
# 45/45 [==============================] - 10s 222ms/step - loss: 0.0143 - accuracy: 0.9780 - jacard_coef: 0.7321 - val_loss: 0.0701 - val_accuracy: 0.9489 - val_jacard_coef: 0.6572
# Epoch 58/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0143 - accuracy: 0.9781 - jacard_coef: 0.7414 - val_loss: 0.0751 - val_accuracy: 0.9484 - val_jacard_coef: 0.6756
# Epoch 59/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0138 - accuracy: 0.9787 - jacard_coef: 0.7430 - val_loss: 0.0782 - val_accuracy: 0.9456 - val_jacard_coef: 0.6800
# Epoch 60/100
# 45/45 [==============================] - 10s 227ms/step - loss: 0.0144 - accuracy: 0.9777 - jacard_coef: 0.7408 - val_loss: 0.0748 - val_accuracy: 0.9459 - val_jacard_coef: 0.6855
# Epoch 61/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0223 - accuracy: 0.9670 - jacard_coef: 0.7094 - val_loss: 0.1009 - val_accuracy: 0.9291 - val_jacard_coef: 0.6706
# Epoch 62/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0180 - accuracy: 0.9736 - jacard_coef: 0.6959 - val_loss: 0.0816 - val_accuracy: 0.9396 - val_jacard_coef: 0.6457
# Epoch 63/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0140 - accuracy: 0.9787 - jacard_coef: 0.7307 - val_loss: 0.0779 - val_accuracy: 0.9477 - val_jacard_coef: 0.6316
# Epoch 64/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0117 - accuracy: 0.9821 - jacard_coef: 0.7508 - val_loss: 0.0579 - val_accuracy: 0.9503 - val_jacard_coef: 0.6490
# Epoch 65/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0109 - accuracy: 0.9832 - jacard_coef: 0.7620 - val_loss: 0.0553 - val_accuracy: 0.9509 - val_jacard_coef: 0.6710
# Epoch 66/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0105 - accuracy: 0.9838 - jacard_coef: 0.7687 - val_loss: 0.0517 - val_accuracy: 0.9479 - val_jacard_coef: 0.6619
# Epoch 67/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0101 - accuracy: 0.9844 - jacard_coef: 0.7728 - val_loss: 0.0459 - val_accuracy: 0.9519 - val_jacard_coef: 0.6676
# Epoch 68/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0100 - accuracy: 0.9844 - jacard_coef: 0.7762 - val_loss: 0.0572 - val_accuracy: 0.9466 - val_jacard_coef: 0.6671
# Epoch 69/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0100 - accuracy: 0.9846 - jacard_coef: 0.7781 - val_loss: 0.0615 - val_accuracy: 0.9451 - val_jacard_coef: 0.6568
# Epoch 70/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0102 - accuracy: 0.9842 - jacard_coef: 0.7790 - val_loss: 0.0739 - val_accuracy: 0.9498 - val_jacard_coef: 0.6982
# Epoch 71/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0108 - accuracy: 0.9833 - jacard_coef: 0.7781 - val_loss: 0.1014 - val_accuracy: 0.9345 - val_jacard_coef: 0.7052
# Epoch 72/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0129 - accuracy: 0.9802 - jacard_coef: 0.7616 - val_loss: 0.1049 - val_accuracy: 0.9472 - val_jacard_coef: 0.7069
# Epoch 73/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0118 - accuracy: 0.9818 - jacard_coef: 0.7646 - val_loss: 0.0710 - val_accuracy: 0.9488 - val_jacard_coef: 0.7111
# Epoch 74/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0109 - accuracy: 0.9831 - jacard_coef: 0.7768 - val_loss: 0.1179 - val_accuracy: 0.9464 - val_jacard_coef: 0.6980
# Epoch 75/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0108 - accuracy: 0.9834 - jacard_coef: 0.7785 - val_loss: 0.0985 - val_accuracy: 0.9403 - val_jacard_coef: 0.6911
# Epoch 76/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0110 - accuracy: 0.9829 - jacard_coef: 0.7731 - val_loss: 0.1532 - val_accuracy: 0.9458 - val_jacard_coef: 0.7054
# Epoch 77/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0109 - accuracy: 0.9830 - jacard_coef: 0.7865 - val_loss: 0.1424 - val_accuracy: 0.9473 - val_jacard_coef: 0.7252
# Epoch 78/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0113 - accuracy: 0.9825 - jacard_coef: 0.7810 - val_loss: 0.0971 - val_accuracy: 0.9476 - val_jacard_coef: 0.7128
# Epoch 79/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0124 - accuracy: 0.9808 - jacard_coef: 0.7736 - val_loss: 0.0877 - val_accuracy: 0.9387 - val_jacard_coef: 0.6607
# Epoch 80/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0115 - accuracy: 0.9824 - jacard_coef: 0.7702 - val_loss: 0.0626 - val_accuracy: 0.9500 - val_jacard_coef: 0.7168
# Epoch 81/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0100 - accuracy: 0.9844 - jacard_coef: 0.7834 - val_loss: 0.0642 - val_accuracy: 0.9473 - val_jacard_coef: 0.6954
# Epoch 82/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0096 - accuracy: 0.9850 - jacard_coef: 0.7922 - val_loss: 0.0570 - val_accuracy: 0.9486 - val_jacard_coef: 0.6795
# Epoch 83/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0091 - accuracy: 0.9857 - jacard_coef: 0.7946 - val_loss: 0.0565 - val_accuracy: 0.9543 - val_jacard_coef: 0.6931
# Epoch 84/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0081 - accuracy: 0.9874 - jacard_coef: 0.8051 - val_loss: 0.0534 - val_accuracy: 0.9541 - val_jacard_coef: 0.7050
# Epoch 85/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0082 - accuracy: 0.9873 - jacard_coef: 0.8085 - val_loss: 0.0580 - val_accuracy: 0.9541 - val_jacard_coef: 0.7089
# Epoch 86/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0081 - accuracy: 0.9873 - jacard_coef: 0.8101 - val_loss: 0.0633 - val_accuracy: 0.9533 - val_jacard_coef: 0.7016
# Epoch 87/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0081 - accuracy: 0.9873 - jacard_coef: 0.8128 - val_loss: 0.0712 - val_accuracy: 0.9522 - val_jacard_coef: 0.7267
# Epoch 88/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0080 - accuracy: 0.9875 - jacard_coef: 0.8179 - val_loss: 0.1057 - val_accuracy: 0.9476 - val_jacard_coef: 0.7288
# Epoch 89/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0080 - accuracy: 0.9875 - jacard_coef: 0.8123 - val_loss: 0.0847 - val_accuracy: 0.9514 - val_jacard_coef: 0.7305
# Epoch 90/100
# 45/45 [==============================] - 10s 222ms/step - loss: 0.0083 - accuracy: 0.9872 - jacard_coef: 0.8132 - val_loss: 0.0935 - val_accuracy: 0.9463 - val_jacard_coef: 0.7308
# Epoch 91/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0088 - accuracy: 0.9863 - jacard_coef: 0.8136 - val_loss: 0.0813 - val_accuracy: 0.9488 - val_jacard_coef: 0.7376
# Epoch 92/100
# 45/45 [==============================] - 10s 219ms/step - loss: 0.0089 - accuracy: 0.9861 - jacard_coef: 0.8124 - val_loss: 0.0719 - val_accuracy: 0.9526 - val_jacard_coef: 0.7441
# Epoch 93/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0085 - accuracy: 0.9866 - jacard_coef: 0.8120 - val_loss: 0.0765 - val_accuracy: 0.9509 - val_jacard_coef: 0.7207
# Epoch 94/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0083 - accuracy: 0.9869 - jacard_coef: 0.8171 - val_loss: 0.0692 - val_accuracy: 0.9522 - val_jacard_coef: 0.7204
# Epoch 95/100
# 45/45 [==============================] - 10s 224ms/step - loss: 0.0083 - accuracy: 0.9870 - jacard_coef: 0.8194 - val_loss: 0.0879 - val_accuracy: 0.9459 - val_jacard_coef: 0.7169
# Epoch 96/100
# 45/45 [==============================] - 10s 226ms/step - loss: 0.0089 - accuracy: 0.9860 - jacard_coef: 0.8141 - val_loss: 0.0970 - val_accuracy: 0.9509 - val_jacard_coef: 0.7226
# Epoch 97/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0086 - accuracy: 0.9866 - jacard_coef: 0.8105 - val_loss: 0.1727 - val_accuracy: 0.9325 - val_jacard_coef: 0.6837
# Epoch 98/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0091 - accuracy: 0.9858 - jacard_coef: 0.8082 - val_loss: 0.2998 - val_accuracy: 0.9059 - val_jacard_coef: 0.6955
# Epoch 99/100
# 45/45 [==============================] - 10s 223ms/step - loss: 0.0091 - accuracy: 0.9859 - jacard_coef: 0.8047 - val_loss: 0.1643 - val_accuracy: 0.9339 - val_jacard_coef: 0.7289
# Epoch 100/100
# 45/45 [==============================] - 10s 225ms/step - loss: 0.0090 - accuracy: 0.9860 - jacard_coef: 0.8088 - val_loss: 0.1556 - val_accuracy: 0.9306 - val_jacard_coef: 0.7358
# Attention ResSegNet execution time is:  0:17:09.052357

# %% [markdown]
# ### If loading the model

# %%
# # model = att_res_SegNet_model
# # skin_AttResSegNet_150epochs_B_focal.hdf5
# model_path = "SegNet_Weights/Skin_Attention_Residual_Segnet_150_epochs_95.9%.hdf5"
# model = tf.keras.models.load_model(model_path, compile=False)

# %%
# model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
#               metrics=['accuracy', jacard_coef])

# att_res_SegNet_history = model.fit(X_train, y_train, 
#                     verbose=1,
#                     batch_size = batch_size,
#                     validation_data=(X_test, y_test ), 
#                     shuffle=False,
#                     epochs=1)

# %% [markdown]
# ### After running the model

# %%
import pandas as pd    
att_res_SegNet_history_df = pd.DataFrame(att_res_SegNet_history.history) 

with open('custom_code_att_res_SegNet_history_df.csv', mode='w') as f:
    att_res_SegNet_history_df.to_csv(f)

# %%
history = att_res_SegNet_history

#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['jacard_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_jacard_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Jacard')
plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
plt.title('Training and validation Jacard')
plt.xlabel('Epochs')
plt.ylabel('Jacard')
plt.legend()
plt.show()

# %%
model = att_res_SegNet_model

import random
test_img_number = random.randint(0, x_test.shape[0]-1)
test_img = x_test[test_img_number]
ground_truth=y_test[test_img_number]

test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print("IoU for the above prediction =", IOU_keras.result().numpy())
# Out:
# IoU for the above prediction = 0.9306538

# %% [markdown]
# ### Calculating mean IoU over the entire dataset

# %%
sum_iou=0
for test_img_number in range(x_train_full.shape[0]):
    test_img = x_train_full[test_img_number]
    ground_truth=y_train_full_exp[test_img_number]

    test_img_input=np.expand_dims(test_img, 0)
    prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IOU_keras = MeanIoU(num_classes=n_classes)  
    IOU_keras.update_state(ground_truth[:,:,0], prediction)
    sum_iou+=IOU_keras.result().numpy()*100
    print("IoU for the current prediction =", IOU_keras.result().numpy())
print("Mean IoU: ",sum_iou/x_train_full.shape[0])
# Out:
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9277767
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9770956
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.955353
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.97066414
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9093318
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.97719973
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.91069996
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9807918
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.75527346
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9396243
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9026228
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.90972775
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.88859564
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.7423451
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.97288114
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9713751
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.96979797
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.8954961
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.90364385
# 1/1 [==============================] - 0s 36ms/step
# IoU for the current prediction = 0.89340764
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.92439777
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.94175625
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.63046205
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.96924245
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.96548676
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.7933464
# 1/1 [==============================] - 0s 35ms/step
# IoU for the current prediction = 0.969322
# 1/1 [==============================] - 0s 70ms/step
# IoU for the current prediction = 0.9702836
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9763933
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.9797313
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9619771
# 1/1 [==============================] - 0s 70ms/step
# IoU for the current prediction = 0.9567697
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.7763196
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.92577815
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9715253
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.95848876
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.97547233
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9019104
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.9432503
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.73344886
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.9405502
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9523214
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.94356024
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9309773
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.9793322
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.93790495
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.95492613
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.96080446
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.92452484
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.96856916
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9739269
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9657876
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9783857
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.7621975
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.89636385
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.8885489
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.95586145
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.96048844
# 1/1 [==============================] - 0s 33ms/step
# IoU for the current prediction = 0.9432346
# 1/1 [==============================] - 0s 35ms/step
# IoU for the current prediction = 0.9815993
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9681157
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.86391187
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.96106577
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.9137976
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.8535011
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9706453
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9744873
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.94686866
# 1/1 [==============================] - 0s 36ms/step
# IoU for the current prediction = 0.96395385
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.7502565
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.86195326
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.95200646
# 1/1 [==============================] - 0s 67ms/step
# IoU for the current prediction = 0.8902337
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9384797
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.8800434
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.9673652
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9516338
# 1/1 [==============================] - 0s 77ms/step
# IoU for the current prediction = 0.9619299
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.8907516
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.94809914
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.94485486
# 1/1 [==============================] - 0s 33ms/step
# IoU for the current prediction = 0.87352467
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.9271326
# 1/1 [==============================] - 0s 36ms/step
# IoU for the current prediction = 0.8687539
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.86008817
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.9160352
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.9765316
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.96575564
# 1/1 [==============================] - 0s 33ms/step
# IoU for the current prediction = 0.9727534
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.9550717
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.88797116
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.593601
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.8953129
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9631138
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.8880472
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.8520982
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.97391355
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.66707826
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.90196633
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9633124
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9565861
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9567338
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.9016471
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.9615843
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.9558999
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.9302118
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.96431774
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.92319226
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9512696
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.8901792
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9693669
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.96448827
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.8874995
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.92796826
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.8823799
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9392342
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.9749559
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.96426237
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.9049451
# 1/1 [==============================] - 0s 37ms/step
# IoU for the current prediction = 0.92524916
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.9401796
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.96282667
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.96368515
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.75402606
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.91217065
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9596375
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.94928616
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9607308
# 1/1 [==============================] - 0s 74ms/step
# IoU for the current prediction = 0.7971553
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.96541977
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.9596169
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.8598263
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9404836
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.96196616
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.96181905
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.8866999
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.9615395
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9458256
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.94555086
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.97020423
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.96728814
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.96816576
# 1/1 [==============================] - 0s 37ms/step
# IoU for the current prediction = 0.9747542
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.97254205
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9783784
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.96871614
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.92530894
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9446187
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.97514725
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9504597
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.9419454
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.96874905
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.96685064
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9622823
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.8984786
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9547862
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9231793
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9740033
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.87566376
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.93562126
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.81874305
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.93804646
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.88859564
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.64303327
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9738173
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9597351
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9672902
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.8929212
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.81720495
# 1/1 [==============================] - 0s 76ms/step
# IoU for the current prediction = 0.8798691
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9311518
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.93945295
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.8428172
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.970152
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.9821811
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.8385395
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9623227
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9681753
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.97308254
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9786842
# 1/1 [==============================] - 0s 80ms/step
# IoU for the current prediction = 0.9606094
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9363754
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.88392603
# 1/1 [==============================] - 0s 37ms/step
# IoU for the current prediction = 0.9672166
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.97865903
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.8888105
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.97939587
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9438619
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.89871407
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.7967007
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.94983745
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.9523214
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.86802274
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.95335025
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.97161436
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.9460734
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9422506
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.962639
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9365175
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9645867
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.9669989
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.96393275
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.9530885
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.80799365
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.8336144
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.8745289
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9389539
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9501054
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9304968
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9718657
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9616821
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.84251213
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9356771
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9473777
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.9783329
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.97233534
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9685409
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9637893
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.93342304
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.95014286
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.85486966
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.9493811
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.89753747
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9304765
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.8921701
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9658485
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.93848896
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9715556
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.83035505
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.95343995
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.94524276
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.83000976
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.92825615
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.81717175
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.74439394
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.91193664
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.96848786
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.94384575
# 1/1 [==============================] - 0s 76ms/step
# IoU for the current prediction = 0.97596616
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9593361
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.85974705
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.6944214
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9475386
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9762325
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.91829073
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.908348
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.9663211
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.7993134
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.90864235
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9577362
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.97016466
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.95830595
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.6959858
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.94368
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9610275
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.8861753
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.9625814
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.9361931
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.939962
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.5119181
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.95722866
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.9644573
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.86338514
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.9385088
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.82720745
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.90074563
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.96266377
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9560586
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.92288345
# 1/1 [==============================] - 0s 74ms/step
# IoU for the current prediction = 0.9402253
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9429261
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.95349264
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.96225077
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.8030756
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.97248244
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9614303
# 1/1 [==============================] - 0s 74ms/step
# IoU for the current prediction = 0.95873034
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.97194433
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.94454086
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.95098174
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9372413
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.73089796
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.9444824
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.9695274
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9697509
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.88646007
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.97120744
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9337256
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.9401741
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.9556463
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.963461
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.9655583
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.9712516
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.96978414
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.98111224
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.9511208
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.89841425
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9152949
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.97707856
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.9425714
# 1/1 [==============================] - 0s 75ms/step
# IoU for the current prediction = 0.9385336
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.97427034
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.9622634
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9696501
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.8914553
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9729357
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.8611573
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.9714093
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9242547
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.90925723
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.90561783
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.8573916
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.8883637
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.8089291
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.972101
# 1/1 [==============================] - 0s 72ms/step
# IoU for the current prediction = 0.9691298
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.96896356
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.9091928
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.82411814
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9388845
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.95042384
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.90825367
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.52963424
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9692553
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.966521
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.82135385
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.9688933
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9678383
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.97724223
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9759845
# 1/1 [==============================] - 0s 47ms/step
# IoU for the current prediction = 0.9596707
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9643018
# 1/1 [==============================] - 0s 67ms/step
# IoU for the current prediction = 0.78328145
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.9233618
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.9707925
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9117913
# 1/1 [==============================] - 0s 71ms/step
# IoU for the current prediction = 0.9755882
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.91474277
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.9443177
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.95429343
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.95204544
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9496733
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9547757
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.97160643
# 1/1 [==============================] - 0s 73ms/step
# IoU for the current prediction = 0.9744006
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9568284
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.90314794
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9611671
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.9116224
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.95528513
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.96218663
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.97071004
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.9753386
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.7976336
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.91364497
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.89905035
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9760927
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.9772829
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.95198107
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.9773487
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.96957624
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.8360032
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.94509065
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.87042886
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.63289225
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.9677809
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.9719687
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.9494733
# 1/1 [==============================] - 0s 74ms/step
# IoU for the current prediction = 0.9586031
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.81207025
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.900958
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.9649767
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.9220357
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.9361316
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.90314424
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.9501851
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.95157176
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.9568956
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.8791151
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9442743
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.94701433
# 1/1 [==============================] - 0s 45ms/step
# IoU for the current prediction = 0.92303157
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.9306805
# 1/1 [==============================] - 0s 42ms/step
# IoU for the current prediction = 0.86649406
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.8350463
# 1/1 [==============================] - 0s 56ms/step
# IoU for the current prediction = 0.924195
# 1/1 [==============================] - 0s 51ms/step
# IoU for the current prediction = 0.97739637
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.9693612
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.96471083
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9749327
# 1/1 [==============================] - 0s 58ms/step
# IoU for the current prediction = 0.8697008
# 1/1 [==============================] - 0s 48ms/step
# IoU for the current prediction = 0.56743944
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.8436182
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.9748396
# 1/1 [==============================] - 0s 41ms/step
# IoU for the current prediction = 0.8914076
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9582621
# 1/1 [==============================] - 0s 62ms/step
# IoU for the current prediction = 0.97760755
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.72635317
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.9323189
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9634274
# 1/1 [==============================] - 0s 70ms/step
# IoU for the current prediction = 0.9643769
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.94536185
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.90056574
# 1/1 [==============================] - 0s 66ms/step
# IoU for the current prediction = 0.96224314
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.94786155
# 1/1 [==============================] - 0s 37ms/step
# IoU for the current prediction = 0.9323499
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.9617306
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9105579
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9261917
# 1/1 [==============================] - 0s 40ms/step
# IoU for the current prediction = 0.7202649
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.93910587
# 1/1 [==============================] - 0s 80ms/step
# IoU for the current prediction = 0.9636182
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.8610489
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.93123287
# 1/1 [==============================] - 0s 50ms/step
# IoU for the current prediction = 0.90835273
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.95333594
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.97340405
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9596957
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9268043
# 1/1 [==============================] - 0s 59ms/step
# IoU for the current prediction = 0.9475414
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.938905
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.9578798
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9641149
# 1/1 [==============================] - 0s 43ms/step
# IoU for the current prediction = 0.77754784
# 1/1 [==============================] - 0s 36ms/step
# IoU for the current prediction = 0.9281619
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.9525111
# 1/1 [==============================] - 0s 61ms/step
# IoU for the current prediction = 0.8126428
# 1/1 [==============================] - 0s 60ms/step
# IoU for the current prediction = 0.9562888
# 1/1 [==============================] - 0s 38ms/step
# IoU for the current prediction = 0.8553196
# 1/1 [==============================] - 0s 44ms/step
# IoU for the current prediction = 0.9697161
# 1/1 [==============================] - 0s 49ms/step
# IoU for the current prediction = 0.96144235
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.91272616
# 1/1 [==============================] - 0s 57ms/step
# IoU for the current prediction = 0.91220844
# 1/1 [==============================] - 0s 64ms/step
# IoU for the current prediction = 0.9664941
# 1/1 [==============================] - 0s 65ms/step
# IoU for the current prediction = 0.9628563
# 1/1 [==============================] - 0s 52ms/step
# IoU for the current prediction = 0.8823653
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.96507835
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.95718676
# 1/1 [==============================] - 0s 53ms/step
# IoU for the current prediction = 0.9132275
# 1/1 [==============================] - 0s 55ms/step
# IoU for the current prediction = 0.95059335
# 1/1 [==============================] - 0s 74ms/step
# IoU for the current prediction = 0.9522946
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.9754188
# 1/1 [==============================] - 0s 39ms/step
# IoU for the current prediction = 0.96939945
# 1/1 [==============================] - 0s 46ms/step
# IoU for the current prediction = 0.95876706
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.97474885
# 1/1 [==============================] - 0s 68ms/step
# IoU for the current prediction = 0.971212
# 1/1 [==============================] - 0s 34ms/step
# IoU for the current prediction = 0.918074
# 1/1 [==============================] - 0s 69ms/step
# IoU for the current prediction = 0.9280002
# 1/1 [==============================] - 0s 54ms/step
# IoU for the current prediction = 0.9728105
# 1/1 [==============================] - 0s 63ms/step
# IoU for the current prediction = 0.85610926
# Mean IoU:  92.26323001914554

# %% [markdown]
# ### Interpretability

# %%
def visualize_conv_layer(int_out, row_size, col_size):
   
  img_index=0

  print(np.shape(int_out))
  
  fig,ax=plt.subplots(row_size,col_size, figsize=(20, 5))
  for row in range(0,row_size):
    for col in range(0,col_size):
      ax[row][col].imshow(int_out[0, :, :, img_index], cmap='jet')
      ax[row][col].axis('off')
      img_index=img_index+1
        
print("Function to Visualize the Output has been Created")
# Out:
# Function to Visualize the Output has been Created

# %% [markdown]
# ### If you are loading the model

# %%
# att_512_2 = tf.keras.models.Model(
#     inputs=model.inputs,
#     outputs=model.get_layer(name="batch_normalization_22").output,
# )
# att_512_1 = tf.keras.models.Model(
#     inputs=model.inputs,
#     outputs=model.get_layer(name="batch_normalization_28").output,
# )
# att_256 = tf.keras.models.Model(
#     inputs=model.inputs,
#     outputs=model.get_layer(name="batch_normalization_34").output,
# )
# att_128 = tf.keras.models.Model(
#     inputs=model.inputs,
#     outputs=model.get_layer(name="batch_normalization_40").output,
# )
# att_64 = tf.keras.models.Model(
#     inputs=model.inputs,
#     outputs=model.get_layer(name="batch_normalization_45").output,
# )

# %%
# selecting the image for interpretability
test_img_input = np.expand_dims(x_test[2], 0)
plt.imshow(x_test[2])

# %%
attention_blocks = [att_512_2, att_512_1, att_256, att_128, att_64]
print("Attention block 1")
in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[0])
int_out = in_to_intermediate.predict(test_img_input)
visualize_conv_layer(int_out,2,8)
# Out:
# Attention block 1
# 1/1 [==============================] - 1s 542ms/step
# (1, 12, 16, 512)

# %%
print("Attention block 2")
in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[1])
int_out = in_to_intermediate.predict(test_img_input)
visualize_conv_layer(int_out,2 ,8)
# Out:
# Attention block 2
# 1/1 [==============================] - 1s 1s/step
# (1, 24, 32, 512)

# %%
print("Attention block 3")
in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[2])
int_out = in_to_intermediate.predict(test_img_input)
visualize_conv_layer(int_out,2,8)
# Out:
# Attention block 3
# 1/1 [==============================] - 1s 945ms/step
# (1, 48, 64, 256)

# %%
print("Attention block 4")
in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[3])
int_out = in_to_intermediate.predict(test_img_input)
visualize_conv_layer(int_out,2,8)
# Out:
# Attention block 4
# WARNING:tensorflow:5 out of the last 455 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2aacbe751d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# (1, 96, 128, 128)

# %%
print("Attention block 5")
in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[4])
int_out = in_to_intermediate.predict(test_img_input)
visualize_conv_layer(int_out,2,8)
# Out:
# Attention block 5
# WARNING:tensorflow:6 out of the last 456 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2aab10e83700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# (1, 192, 256, 64)

# %% [markdown]
# ### Max Intensity Projection (MPI)

# %%
import SimpleITK as sitk

# %% [markdown]
# #### Constructing the numpy image stack

# %%
import numpy as np
import nibabel as nib

# %%
for i in range(5):
    in_to_intermediate = Model(inputs=model.inputs, outputs=attention_blocks[i])
    int_out = in_to_intermediate.predict(test_img_input)

    path_to_save = 'attention_nii_files/atten_'+str(i)+'.nii'

    converted_array = np.array(int_out[0], dtype=np.float32) # You need to replace normal array by yours
    affine = np.eye(4)
    nifti_file = nib.Nifti1Image(converted_array, affine)

    nib.save(nifti_file, path_to_save)
# Out:
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %%
def make_mips(image_path, output_dir):
    image = sitk.ReadImage(image_path)
    image_size = image.GetSize()

    basename = os.path.basename(image_path)
    if not os.path.isdir(output_dir):
        os.makedirs(output_dir)

    for dim in range(3):
        projection = sitk.MaximumProjection(image, dim)

        if image_size[dim] % 2:  # odd number
            voxel = [0, 0, 0]
            voxel[dim] = (image_size[dim] - 1) / 2
            origin = image.TransformIndexToPhysicalPoint(voxel)
        else:  # even
            voxel1 = np.array([0, 0, 0], int)
            voxel2 = np.array([0, 0, 0], int)
            voxel1[dim] = image_size[dim] / 2 - 1
            voxel2[dim] = image_size[dim] / 2
            point1 = np.array(image.TransformIndexToPhysicalPoint(voxel1.tolist()))
            point2 = np.array(image.TransformIndexToPhysicalPoint(voxel2.tolist()))
            origin = np.mean(np.vstack((point1, point2)), 0)
        projection.SetOrigin(origin)
        projection.SetDirection(image.GetDirection())
        proj_basename = basename.replace('.nii.gz', '_mip_{}.nii.gz'.format(dim))
        sitk.WriteImage(projection, os.path.join(output_dir, proj_basename))

# %%
for i in range(5):

    image_path = 'attention_nii_files/atten_'+str(i)+'.nii'
    output_dir = 'attention_nii_files/attention_mip/'
    make_mips(image_path, output_dir)

# %%
for i in range(5):
    out_np_path = 'attention_nii_files/attention_mip/atten_'+str(i)+'.nii'
    out_img = nib.load(out_np_path)
    out_img = np.array(out_img.dataobj, dtype='int16')
    out_img = np.squeeze(out_img)
    cv2.imwrite('img_'+str(i)+'.png', out_img)
#     plt.imsave('img_'+str(i)+'.png', out_img)

# %%
fname = 'attention_nii_files/Atten_maps/img_0.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/Atten_maps/img_1.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/Atten_maps/img_2.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/Atten_maps/img_3.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/Atten_maps/img_4.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %% [markdown]
# ### Visualizing convolutional blocks

# %%
conv_enc_blocks = [conv_64, conv_128, conv_256, conv_512_1, conv_512_2]

# %%
conv_dec_blocks = [up_conv_512_2, up_conv_512_1, up_conv_256, up_conv_128, up_conv_64]

# %%
for i in range(5):
    in_to_intermediate = Model(inputs=model.inputs, outputs=conv_enc_blocks[i])
    int_out = in_to_intermediate.predict(test_img_input)

    path_to_save = 'attention_nii_files/conv_enc_mip/conv_enc_'+str(i)+'.nii'

    converted_array = np.array(int_out[0], dtype=np.float32) # You need to replace normal array by yours
    affine = np.eye(4)
    nifti_file = nib.Nifti1Image(converted_array, affine)

    nib.save(nifti_file, path_to_save)
# Out:
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 363ms/step

# %%
for i in range(5):
    image_path = 'attention_nii_files/conv_enc_mip/conv_enc_'+str(i)+'.nii'
    output_dir = 'attention_nii_files/conv_enc_mpi/'
    make_mips(image_path, output_dir)

# %%
for i in range(5):
    out_np_path = 'attention_nii_files/conv_enc_mpi/conv_enc_'+str(i)+'.nii'
    out_img = nib.load(out_np_path)
    out_img = np.array(out_img.dataobj, dtype='int16')
    out_img = np.squeeze(out_img)
    cv2.imwrite('attention_nii_files/conv_enc_mpi/img_'+str(i)+'.png', out_img)

# %%
fname = 'attention_nii_files/conv_enc_mpi/img_0.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_enc_mpi/img_1.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_enc_mpi/img_2.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_enc_mpi/img_3.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_enc_mpi/img_4.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %% [markdown]
# ### Visualizing deconvolution blocks

# %%
for i in range(5):
    in_to_intermediate = Model(inputs=model.inputs, outputs=conv_dec_blocks[i])
    int_out = in_to_intermediate.predict(test_img_input)

    path_to_save = 'attention_nii_files/conv_dec_mip/conv_dec_'+str(i)+'.nii'

    converted_array = np.array(int_out[0], dtype=np.float32) # You need to replace normal array by yours
    affine = np.eye(4)
    nifti_file = nib.Nifti1Image(converted_array, affine)

    nib.save(nifti_file, path_to_save)
# Out:
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 808ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %%
for i in range(5):

    image_path = 'attention_nii_files/conv_dec_mip/conv_dec_'+str(i)+'.nii'
    output_dir = 'attention_nii_files/conv_dec_mpi/'
    make_mips(image_path, output_dir)

# %%
for i in range(5):
    out_np_path = 'attention_nii_files/conv_dec_mpi/conv_dec_'+str(i)+'.nii'
    out_img = nib.load(out_np_path)
    out_img = np.array(out_img.dataobj, dtype='int16')
    out_img = np.squeeze(out_img)
    cv2.imwrite('attention_nii_files/conv_dec_mpi/img_'+str(i)+'.png', out_img)

# %%
fname = 'attention_nii_files/conv_dec_mpi/img_0.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_dec_mpi/img_1.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_dec_mpi/img_2.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_dec_mpi/img_3.png'
plt.imshow(Image.open(fname), cmap = 'jet')

# %%
fname = 'attention_nii_files/conv_dec_mpi/img_4.png'
plt.imshow(Image.open(fname), cmap = 'jet')
