# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# 2023-02-05 21:43:41.589491: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-05 21:43:41.805057: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-05 21:43:42.615747: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-02-05 21:43:42.615824: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-02-05 21:43:42.615837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('Skin_Lesion_Dataset/train_imgs/trainx/*.jpg'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('Skin_Lesion_Dataset/train_masks/trainy/*.jpg'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 3600
# Length of the Test Set       : 500
# Length of the Validation Set : 900

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt SGD optimization algorithm, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * On large datasets, SGD can converge faster than batch training because it performs updates more frequently. We can get away with this because the data often contains redundant information, so the gradient can be reasonably approximated without using the full dataset. Minibatch training can be faster than training on single data points because it can take advantage of vectorized operations to process the entire minibatch at once. The stochastic nature of online/minibatch training can also make it possible to hop out of local minima that might otherwise trap batch training.
# * The learning rate is the conventional 0.001.

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://www.researchgate.net/profile/Adam_Czajka2/publication/326151825/figure/fig2/AS:647447659438083@1531374959468/Encoder-decoder-architecture-of-SegNet-Inference-takes-place-from-left-to-right-Size-of.png)

# %% [markdown]
# * The architecture we are implementing is suggested in [this](https://arxiv.org/pdf/1511.00561.pdf) paper.
# * The advised parameters can't exactly be applied to our problem.
# * We will switch the final activation function from **Softmax** to **Sigmoid** as using softmax was producing blank dark images.
# * The loss function in segnet is suggested **categorical crossentropy** due to it's genral use of muliclass segmentation problem but in our case we only have 1 class i.e. the melanoma. So, we will use **binary crossentropy**

# %%
def segnet(epochs_num,savename):

    # Encoding layer
    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    model.save(savename)
    return model,hist

# %% [markdown]
# **After 1 epoch**

# %%
model, hist = segnet(1, 'segnet_1_epoch.h5')
# Out:
# 2023-02-05 21:45:53.798105: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-05 21:45:54.333933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13814 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 192, 256, 3)]     0
#
#  conv1 (Conv2D)              (None, 192, 256, 64)      1792
#
#  bn1 (BatchNormalization)    (None, 192, 256, 64)      256
#
#  activation (Activation)     (None, 192, 256, 64)      0
#
#  conv2 (Conv2D)              (None, 192, 256, 64)      36928
#
#  bn2 (BatchNormalization)    (None, 192, 256, 64)      256
#
#  activation_1 (Activation)   (None, 192, 256, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 96, 128, 64)      0
#  )
#
#  conv3 (Conv2D)              (None, 96, 128, 128)      73856
#
#  bn3 (BatchNormalization)    (None, 96, 128, 128)      512
#
#  activation_2 (Activation)   (None, 96, 128, 128)      0
#
#  conv4 (Conv2D)              (None, 96, 128, 128)      147584
#
#  bn4 (BatchNormalization)    (None, 96, 128, 128)      512
#
#  activation_3 (Activation)   (None, 96, 128, 128)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 64, 128)      0
#  2D)
#
#  conv5 (Conv2D)              (None, 48, 64, 256)       295168
#
#  bn5 (BatchNormalization)    (None, 48, 64, 256)       1024
#
#  activation_4 (Activation)   (None, 48, 64, 256)       0
#
#  conv6 (Conv2D)              (None, 48, 64, 256)       590080
#
#  bn6 (BatchNormalization)    (None, 48, 64, 256)       1024
#
#  activation_5 (Activation)   (None, 48, 64, 256)       0
#
#  conv7 (Conv2D)              (None, 48, 64, 256)       590080
#
#  bn7 (BatchNormalization)    (None, 48, 64, 256)       1024
#
#  activation_6 (Activation)   (None, 48, 64, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 32, 256)      0
#  2D)
#
#  conv8 (Conv2D)              (None, 24, 32, 512)       1180160
#
#  bn8 (BatchNormalization)    (None, 24, 32, 512)       2048
#
#  activation_7 (Activation)   (None, 24, 32, 512)       0
#
#  conv9 (Conv2D)              (None, 24, 32, 512)       2359808
#
#  bn9 (BatchNormalization)    (None, 24, 32, 512)       2048
#
#  activation_8 (Activation)   (None, 24, 32, 512)       0
#
#  conv10 (Conv2D)             (None, 24, 32, 512)       2359808
#
#  bn10 (BatchNormalization)   (None, 24, 32, 512)       2048
#
#  activation_9 (Activation)   (None, 24, 32, 512)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 16, 512)      0
#  2D)
#
#  conv11 (Conv2D)             (None, 12, 16, 512)       2359808
#
#  bn11 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_10 (Activation)  (None, 12, 16, 512)       0
#
#  conv12 (Conv2D)             (None, 12, 16, 512)       2359808
#
#  bn12 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_11 (Activation)  (None, 12, 16, 512)       0
#
#  conv13 (Conv2D)             (None, 12, 16, 512)       2359808
#
#  bn13 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_12 (Activation)  (None, 12, 16, 512)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 8, 512)        0
#  2D)
#
#  fc1 (Dense)                 (None, 6, 8, 1024)        525312
#
#  fc2 (Dense)                 (None, 6, 8, 1024)        1049600
#
#  up_sampling2d (UpSampling2D  (None, 12, 16, 1024)     0
#  )
#
#  deconv1 (Conv2DTranspose)   (None, 12, 16, 512)       4719104
#
#  bn14 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_13 (Activation)  (None, 12, 16, 512)       0
#
#  deconv2 (Conv2DTranspose)   (None, 12, 16, 512)       2359808
#
#  bn15 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_14 (Activation)  (None, 12, 16, 512)       0
#
#  deconv3 (Conv2DTranspose)   (None, 12, 16, 512)       2359808
#
#  bn16 (BatchNormalization)   (None, 12, 16, 512)       2048
#
#  activation_15 (Activation)  (None, 12, 16, 512)       0
#
#  up_sampling2d_1 (UpSampling  (None, 24, 32, 512)      0
#  2D)
#
#  deconv4 (Conv2DTranspose)   (None, 24, 32, 512)       2359808
#
#  bn17 (BatchNormalization)   (None, 24, 32, 512)       2048
#
#  activation_16 (Activation)  (None, 24, 32, 512)       0
#
#  deconv5 (Conv2DTranspose)   (None, 24, 32, 512)       2359808
#
#  bn18 (BatchNormalization)   (None, 24, 32, 512)       2048
#
#  activation_17 (Activation)  (None, 24, 32, 512)       0
#
#  deconv6 (Conv2DTranspose)   (None, 24, 32, 256)       1179904
#
#  bn19 (BatchNormalization)   (None, 24, 32, 256)       1024
#
#  activation_18 (Activation)  (None, 24, 32, 256)       0
#
#  up_sampling2d_2 (UpSampling  (None, 48, 64, 256)      0
#  2D)
#
#  deconv7 (Conv2DTranspose)   (None, 48, 64, 256)       590080
#
#  bn20 (BatchNormalization)   (None, 48, 64, 256)       1024
#
#  activation_19 (Activation)  (None, 48, 64, 256)       0
#
#  deconv8 (Conv2DTranspose)   (None, 48, 64, 256)       590080
#
#  bn21 (BatchNormalization)   (None, 48, 64, 256)       1024
#
#  activation_20 (Activation)  (None, 48, 64, 256)       0
#
#  deconv9 (Conv2DTranspose)   (None, 48, 64, 128)       295040
#
#  bn22 (BatchNormalization)   (None, 48, 64, 128)       512
#
#  activation_21 (Activation)  (None, 48, 64, 128)       0
#
#  up_sampling2d_3 (UpSampling  (None, 96, 128, 128)     0
#  2D)
#
#  deconv10 (Conv2DTranspose)  (None, 96, 128, 128)      147584
#
#  bn23 (BatchNormalization)   (None, 96, 128, 128)      512
#
#  activation_22 (Activation)  (None, 96, 128, 128)      0
#
#  deconv11 (Conv2DTranspose)  (None, 96, 128, 64)       73792
#
#  bn24 (BatchNormalization)   (None, 96, 128, 64)       256
#
#  activation_23 (Activation)  (None, 96, 128, 64)       0
#
#  up_sampling2d_4 (UpSampling  (None, 192, 256, 64)     0
#  2D)
#
#  deconv12 (Conv2DTranspose)  (None, 192, 256, 64)      36928
#
#  bn25 (BatchNormalization)   (None, 192, 256, 64)      256
#
#  activation_24 (Activation)  (None, 192, 256, 64)      0
#
#  deconv13 (Conv2DTranspose)  (None, 192, 256, 1)       577
#
#  bn26 (BatchNormalization)   (None, 192, 256, 1)       4
#
#  activation_25 (Activation)  (None, 192, 256, 1)       0
#
#  reshape (Reshape)           (None, 192, 256)          0
#
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# 2023-02-05 21:46:02.215889: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 108/200 [===============>..............] - ETA: 17s - loss: -628.2487 - iou: 0.1708 - dice_coef: 1.8959 - precision: 0.2563 - recall: 0.9968 - accuracy: 0.1172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model, hist = segnet(1, 'segnet_1_epoch.h5')
#
# Cell In[20], line 112, in segnet(epochs_num, savename)
#     109 model.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
#     110               , metrics=[iou, dice_coef, precision, recall, accuracy])
#     111 model.summary()
# --> 112 hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
#     114 model.save(savename)
#     115 return model,hist
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/engine/training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/utils/tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/utils/tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
# Encoding layer
img_input = Input(shape= (192, 256, 3))
x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
x = BatchNormalization(name='bn9')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
x = BatchNormalization(name='bn10')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
x = BatchNormalization(name='bn11')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
x = BatchNormalization(name='bn12')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
x = BatchNormalization(name='bn13')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)
# Decoding Layer 
x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn14')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn15')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn16')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn17')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='bn18')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='bn19')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='bn20')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
x = BatchNormalization(name='bn21')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
x = BatchNormalization(name='bn22')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
x = BatchNormalization(name='bn23')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
x = BatchNormalization(name='bn24')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
x = BatchNormalization(name='bn25')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
x = BatchNormalization(name='bn26')(x)
x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_0 = Model(inputs=img_input, outputs=pred)

model_0.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_0.load_weights('segnet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 4s 10ms/step
# ________________________
# IOU:       |   67.65  |
# Dice Coef: |   38.60  |
# Precision: |   39.04  |
# Recall:    |   44.09  |
# Accuracy:  |   59.50  |
# Loss:      |   82.62  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 17ms/step
# ________________________
# IOU:       |   66.74  |
# Dice Coef: |   37.77  |
# Precision: |   35.81  |
# Recall:    |   45.83  |
# Accuracy:  |   57.62  |
# Loss:      |   82.71  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   67.08  |
# Dice Coef: |   37.69  |
# Precision: |   36.26  |
# Recall:    |   43.76  |
# Accuracy:  |   58.18  |
# Loss:      |   79.54  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = segnet(epochs_num= 100, savename= 'segnet_100_epoch.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 192, 256, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 192, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_53 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_54 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 96, 128, 64)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 96, 128, 128)      73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_55 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_56 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 48, 64, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 48, 64, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_57 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_58 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_59 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 24, 32, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 24, 32, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_62 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 12, 16, 512)       0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_63 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_64 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_65 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 8, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 6, 8, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 6, 8, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 12, 16, 1024)      0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 12, 16, 512)       4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_66 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_67 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_68 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_69 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_70 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 24, 32, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 24, 32, 256)       1024
# _________________________________________________________________
# activation_71 (Activation)   (None, 24, 32, 256)       0
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_73 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 48, 64, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 48, 64, 128)       512
# _________________________________________________________________
# activation_74 (Activation)   (None, 48, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_75 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 96, 128, 64)       73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 96, 128, 64)       256
# _________________________________________________________________
# activation_76 (Activation)   (None, 96, 128, 64)       0
# _________________________________________________________________
# up_sampling2d_15 (UpSampling (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_77 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 192, 256, 1)       577
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 192, 256, 1)       4
# _________________________________________________________________
# activation_78 (Activation)   (None, 192, 256, 1)       0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 192, 256)          0
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 15s 42ms/step - loss: 0.7375 - iou: 0.6689 - dice_coef: 0.4101 - precision: 0.3513 - recall: 0.6537 - accuracy: 0.4997 - val_loss: 1.1780 - val_iou: 0.6713 - val_dice_coef: 0.2978 - val_precision: 0.3237 - val_recall: 0.2263 - val_accuracy: 0.6099
# Epoch 2/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.6212 - iou: 0.7199 - dice_coef: 0.4639 - precision: 0.4771 - recall: 0.8140 - accuracy: 0.6495 - val_loss: 0.7666 - val_iou: 0.6706 - val_dice_coef: 0.4572 - val_precision: 0.3677 - val_recall: 0.8121 - val_accuracy: 0.5044
# Epoch 3/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.4993 - iou: 0.7806 - dice_coef: 0.5389 - precision: 0.6457 - recall: 0.8319 - accuracy: 0.7950 - val_loss: 0.7394 - val_iou: 0.6876 - val_dice_coef: 0.5067 - val_precision: 0.4001 - val_recall: 0.9006 - val_accuracy: 0.5454
# Epoch 4/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.4511 - iou: 0.8042 - dice_coef: 0.5620 - precision: 0.7496 - recall: 0.8437 - accuracy: 0.8566 - val_loss: 0.6748 - val_iou: 0.7226 - val_dice_coef: 0.5696 - val_precision: 0.4658 - val_recall: 0.9611 - val_accuracy: 0.6424
# Epoch 5/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.4228 - iou: 0.8196 - dice_coef: 0.5806 - precision: 0.7985 - recall: 0.8585 - accuracy: 0.8822 - val_loss: 0.5629 - val_iou: 0.7658 - val_dice_coef: 0.5917 - val_precision: 0.5562 - val_recall: 0.9464 - val_accuracy: 0.7466
# Epoch 6/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.3989 - iou: 0.8325 - dice_coef: 0.5976 - precision: 0.8325 - recall: 0.8743 - accuracy: 0.9017 - val_loss: 0.4784 - val_iou: 0.8010 - val_dice_coef: 0.6126 - val_precision: 0.6396 - val_recall: 0.9435 - val_accuracy: 0.8170
# Epoch 7/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.3918 - iou: 0.8377 - dice_coef: 0.6009 - precision: 0.8326 - recall: 0.8757 - accuracy: 0.9005 - val_loss: 0.4537 - val_iou: 0.8120 - val_dice_coef: 0.6183 - val_precision: 0.6651 - val_recall: 0.9377 - val_accuracy: 0.8344
# Epoch 8/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.3717 - iou: 0.8484 - dice_coef: 0.6155 - precision: 0.8535 - recall: 0.8912 - accuracy: 0.9139 - val_loss: 0.4111 - val_iou: 0.8283 - val_dice_coef: 0.6236 - val_precision: 0.7212 - val_recall: 0.9287 - val_accuracy: 0.8658
# Epoch 9/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.3615 - iou: 0.8544 - dice_coef: 0.6216 - precision: 0.8609 - recall: 0.8939 - accuracy: 0.9179 - val_loss: 0.3720 - val_iou: 0.8465 - val_dice_coef: 0.6335 - val_precision: 0.7866 - val_recall: 0.9092 - val_accuracy: 0.8941
# Epoch 10/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.3493 - iou: 0.8611 - dice_coef: 0.6305 - precision: 0.8773 - recall: 0.8955 - accuracy: 0.9238 - val_loss: 0.3547 - val_iou: 0.8562 - val_dice_coef: 0.6368 - val_precision: 0.8234 - val_recall: 0.8833 - val_accuracy: 0.9052
# Epoch 11/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0
100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1688 - iou: 0.9489 - dice_coef: 0.7979 - precision: 0.9335 - recall: 0.9523 - accuracy: 0.9629 - val_loss: 0.1866 - val_iou: 0.9408 - val_dice_coef: 0.7855 - val_precision: 0.9121 - val_recall: 0.9302 - val_accuracy: 0.9499
# Epoch 64/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1565 - iou: 0.9544 - dice_coef: 0.8085 - precision: 0.9503 - recall: 0.9556 - accuracy: 0.9694 - val_loss: 0.1842 - val_iou: 0.9418 - val_dice_coef: 0.7861 - val_precision: 0.9258 - val_recall: 0.9158 - val_accuracy: 0.9503
# Epoch 65/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1583 - iou: 0.9534 - dice_coef: 0.8067 - precision: 0.9427 - recall: 0.9586 - accuracy: 0.9683 - val_loss: 0.1875 - val_iou: 0.9399 - val_dice_coef: 0.7883 - val_precision: 0.9015 - val_recall: 0.9383 - val_accuracy: 0.9483
# Epoch 66/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1562 - iou: 0.9543 - dice_coef: 0.8094 - precision: 0.9505 - recall: 0.9513 - accuracy: 0.9684 - val_loss: 0.1839 - val_iou: 0.9422 - val_dice_coef: 0.7865 - val_precision: 0.9264 - val_recall: 0.9139 - val_accuracy: 0.9499
# Epoch 67/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1561 - iou: 0.9545 - dice_coef: 0.8117 - precision: 0.9431 - recall: 0.9589 - accuracy: 0.9677 - val_loss: 0.1820 - val_iou: 0.9430 - val_dice_coef: 0.7924 - val_precision: 0.9055 - val_recall: 0.9443 - val_accuracy: 0.9515
# Epoch 68/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1537 - iou: 0.9553 - dice_coef: 0.8125 - precision: 0.9432 - recall: 0.9613 - accuracy: 0.9690 - val_loss: 0.1786 - val_iou: 0.9441 - val_dice_coef: 0.7932 - val_precision: 0.9202 - val_recall: 0.9296 - val_accuracy: 0.9524
# Epoch 69/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1473 - iou: 0.9582 - dice_coef: 0.8184 - precision: 0.9561 - recall: 0.9577 - accuracy: 0.9720 - val_loss: 0.1782 - val_iou: 0.9444 - val_dice_coef: 0.7940 - val_precision: 0.9218 - val_recall: 0.9276 - val_accuracy: 0.9524
# Epoch 70/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1499 - iou: 0.9569 - dice_coef: 0.8167 - precision: 0.9542 - recall: 0.9560 - accuracy: 0.9705 - val_loss: 0.1797 - val_iou: 0.9438 - val_dice_coef: 0.7913 - val_precision: 0.9351 - val_recall: 0.9112 - val_accuracy: 0.9517
# Epoch 71/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1472 - iou: 0.9581 - dice_coef: 0.8191 - precision: 0.9507 - recall: 0.9611 - accuracy: 0.9714 - val_loss: 0.1763 - val_iou: 0.9453 - val_dice_coef: 0.7955 - val_precision: 0.9292 - val_recall: 0.9219 - val_accuracy: 0.9529
# Epoch 72/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1497 - iou: 0.9570 - dice_coef: 0.8183 - precision: 0.9512 - recall: 0.9563 - accuracy: 0.9694 - val_loss: 0.1766 - val_iou: 0.9454 - val_dice_coef: 0.7939 - val_precision: 0.9366 - val_recall: 0.9136 - val_accuracy: 0.9529
# Epoch 73/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1439 - iou: 0.9595 - dice_coef: 0.8230 - precision: 0.9538 - recall: 0.9611 - accuracy: 0.9723 - val_loss: 0.1770 - val_iou: 0.9451 - val_dice_coef: 0.7933 - val_precision: 0.9402 - val_recall: 0.9080 - val_accuracy: 0.9522
# Epoch 74/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.
100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1416 - iou: 0.9591 - dice_coef: 0.8277 - precision: 0.9523 - recall: 0.9565 - accuracy: 0.9702 - val_loss: 0.1646 - val_iou: 0.9491 - val_dice_coef: 0.8125 - val_precision: 0.9264 - val_recall: 0.9312 - val_accuracy: 0.9550
# Epoch 85/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1409 - iou: 0.9594 - dice_coef: 0.8288 - precision: 0.9454 - recall: 0.9631 - accuracy: 0.9702 - val_loss: 0.1640 - val_iou: 0.9493 - val_dice_coef: 0.8114 - val_precision: 0.9270 - val_recall: 0.9318 - val_accuracy: 0.9554
# Epoch 86/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1362 - iou: 0.9617 - dice_coef: 0.8322 - precision: 0.9552 - recall: 0.9603 - accuracy: 0.9726 - val_loss: 0.1684 - val_iou: 0.9476 - val_dice_coef: 0.8103 - val_precision: 0.9195 - val_recall: 0.9307 - val_accuracy: 0.9525
# Epoch 87/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1372 - iou: 0.9613 - dice_coef: 0.8322 - precision: 0.9548 - recall: 0.9591 - accuracy: 0.9719 - val_loss: 0.1640 - val_iou: 0.9494 - val_dice_coef: 0.8133 - val_precision: 0.9209 - val_recall: 0.9354 - val_accuracy: 0.9543
# Epoch 88/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1345 - iou: 0.9624 - dice_coef: 0.8348 - precision: 0.9550 - recall: 0.9612 - accuracy: 0.9728 - val_loss: 0.1638 - val_iou: 0.9496 - val_dice_coef: 0.8109 - val_precision: 0.9329 - val_recall: 0.9236 - val_accuracy: 0.9550
# Epoch 89/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1366 - iou: 0.9609 - dice_coef: 0.8322 - precision: 0.9495 - recall: 0.9624 - accuracy: 0.9716 - val_loss: 0.1661 - val_iou: 0.9482 - val_dice_coef: 0.8124 - val_precision: 0.9159 - val_recall: 0.9386 - val_accuracy: 0.9535
# Epoch 90/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1364 - iou: 0.9612 - dice_coef: 0.8322 - precision: 0.9514 - recall: 0.9593 - accuracy: 0.9715 - val_loss: 0.1673 - val_iou: 0.9478 - val_dice_coef: 0.8108 - val_precision: 0.9207 - val_recall: 0.9309 - val_accuracy: 0.9528
# Epoch 91/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1383 - iou: 0.9604 - dice_coef: 0.8312 - precision: 0.9487 - recall: 0.9595 - accuracy: 0.9704 - val_loss: 0.1715 - val_iou: 0.9462 - val_dice_coef: 0.8054 - val_precision: 0.9418 - val_recall: 0.8994 - val_accuracy: 0.9503
# Epoch 92/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1295 - iou: 0.9644 - dice_coef: 0.8394 - precision: 0.9548 - recall: 0.9666 - accuracy: 0.9746 - val_loss: 0.1694 - val_iou: 0.9467 - val_dice_coef: 0.8136 - val_precision: 0.9082 - val_recall: 0.9395 - val_accuracy: 0.9508
# Epoch 93/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1299 - iou: 0.9640 - dice_coef: 0.8392 - precision: 0.9584 - recall: 0.9618 - accuracy: 0.9741 - val_loss: 0.1623 - val_iou: 0.9499 - val_dice_coef: 0.8133 - val_precision: 0.9424 - val_recall: 0.9136 - val_accuracy: 0.9550
# Epoch 94/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1360 - iou: 0.9612 - dice_coef: 0.8351 - precision: 0.9495 - recall: 0.9621 - accuracy: 0.9709 - val_loss: 0.1613 - val_iou: 0.9503 - val_dice_coef: 0.8176 - val_precision: 0.9204 - val_recall: 0.9388 - val_accuracy: 0.9551
# Epoch 95/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1342 - iou: 0.9617 - dice_coef: 0.8337 - precision: 0.9466 - recall: 0.9634 - accuracy: 0.9720 - val_loss: 0.1647 - val_iou: 0.9482 - val_dice_coef: 0.8177 - val_precision: 0.9117 - val_recall: 0.9410 - val_accuracy: 0.9526
# Epoch 96/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1250 - iou: 0.9662 - dice_coef: 0.8447 - precision: 0.9598 - recall: 0.9651 - accuracy: 0.9755 - val_loss: 0.1647 - val_iou: 0.9482 - val_dice_coef: 0.8175 - val_precision: 0.9075 - val_recall: 0.9465 - val_accuracy: 0.9528
# Epoch 97/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1237 - iou: 0.9666 - dice_coef: 0.8466 - precision: 0.9585 - recall: 0.9668 - accuracy: 0.9757 - val_loss: 0.1618 - val_iou: 0.9499 - val_dice_coef: 0.8177 - val_precision: 0.9144 - val_recall: 0.9423 - val_accuracy: 0.9541
# Epoch 98/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1305 - iou: 0.9632 - dice_coef: 0.8390 - precision: 0.9544 - recall: 0.9606 - accuracy: 0.9729 - val_loss: 0.1576 - val_iou: 0.9518 - val_dice_coef: 0.8187 - val_precision: 0.9338 - val_recall: 0.9270 - val_accuracy: 0.9563
# Epoch 99/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1295 - iou: 0.9639 - dice_coef: 0.8401 - precision: 0.9554 - recall: 0.9639 - accuracy: 0.9738 - val_loss: 0.1582 - val_iou: 0.9514 - val_dice_coef: 0.8194 - val_precision: 0.9304 - val_recall: 0.9283 - val_accuracy: 0.9555
# Epoch 100/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.1238 - iou: 0.9664 - dice_coef: 0.8460 - precision: 0.9580 - recall: 0.9665 - accuracy: 0.9756 - val_loss: 0.1582 - val_iou: 0.9515 - val_dice_coef: 0.8217 - val_precision: 0.9173 - val_recall: 0.9417 - val_accuracy: 0.9549

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_1.load_weights('segnet_100_epoch.h5')

# %% [markdown]
# Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 4s 11ms/step
# ________________________
# IOU:       |   97.10  |
# Dice Coef: |   85.32  |
# Precision: |   95.93  |
# Recall:    |   97.60  |
# Accuracy:  |   97.94  |
# Loss:      |   11.33  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 7ms/step
# ________________________
# IOU:       |   93.90  |
# Dice Coef: |   80.66  |
# Precision: |   89.48  |
# Recall:    |   92.39  |
# Accuracy:  |   94.27  |
# Loss:      |   18.34  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   95.15  |
# Dice Coef: |   82.17  |
# Precision: |   91.73  |
# Recall:    |   94.17  |
# Accuracy:  |   95.49  |
# Loss:      |   15.82  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_0.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.
