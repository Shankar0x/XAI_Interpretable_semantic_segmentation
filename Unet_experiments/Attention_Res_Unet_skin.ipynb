# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from datetime import datetime 
import cv2
from PIL import Image
from keras import backend, optimizers
# Out:
# 2023-03-07 17:51:14.004002: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 17:51:14.201996: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-07 17:51:14.877664: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-03-07 17:51:14.877741: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/cudnn-8.4/8.4/lib64:/cm/local/apps/cuda/libs/current/lib64:/cm/shared/apps/cuda11.2/toolkit/11.2.0/targets/x86_64-linux/lib:/cm/local/apps/gcc/7.2.0/lib:/cm/local/apps/gcc/7.2.0/lib64:/home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/
# 2023-03-07 17:51:14.877751: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
image_directory = 'imgs/Resized_Skin_Lesion_Dataset/Train_images/Trainx/'
mask_directory = 'imgs/Resized_Skin_Lesion_Dataset/Train_masks/Trainy/'

# %%
SIZE = 256
image_dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
mask_dataset = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'bmp'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB )
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

# %%
masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'bmp'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

# %%
#Normalize images
image_dataset = np.array(image_dataset)/255.
#D not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.10, random_state = 0)

# %%
X_train.shape
# Out:
# (180, 256, 256, 3)

# %%
y_train.shape
# Out:
# (180, 256, 256, 1)

# %%
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(X_train[image_number], (256, 256, 3)))
plt.subplot(122)
plt.imshow(np.reshape(y_train[image_number], (256, 256)), cmap='gray')
plt.show()

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8

#FOCAL LOSS AND DICE METRIC
#Focal loss helps focus more on tough to segment classes.
from focal_loss import BinaryFocalLoss

# %%
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape 
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)


def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).
    
    1. conv - BN - Activation - conv - BN - Activation 
                                          - shortcut  - BN - shortcut+BN
                                          
    2. conv - BN - Activation - conv - BN   
                                     - shortcut  - BN - shortcut+BN - Activation                                     
    
    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def Attention_ResUNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Rsidual UNet, with attention 
    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    # input data
    # dimension of the image depth
    inputs = layers.Input(input_shape, dtype=tf.float32)
    axis = 3

    # Downsampling layers
    # DownRes 1, double residual convolution + pooling
    conv_128 = res_conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = res_conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = res_conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = res_conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = res_conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=axis)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=axis)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=axis)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=axis)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=axis)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs, conv_final, name="AttentionResUNet")
    return model

# %%
att_res_unet_model = Attention_ResUNet(input_shape)

att_res_unet_model.compile(optimizer=Adam(lr = 1e-2), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coef])


# att_res_unet_model.compile(optimizer=Adam(lr = 1e-3), loss='binary_crossentropy', 
#               metrics=['accuracy', jacard_coef])

print(att_res_unet_model.summary())


start3 = datetime.now() 
att_res_unet_history = att_res_unet_model.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ), 
                    shuffle=False,
                    epochs=150)
stop3 = datetime.now()

#Execution time of the model 
execution_time_AttResUnet = stop3-start3
print("Attention ResUnet execution time is: ", execution_time_AttResUnet)

att_res_unet_model.save('skin_AttResUnet_50epochs_B_focal.hdf5')
# Out:
# 2023-03-07 17:52:12.655612: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 17:52:13.325333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14625 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 256, 256, 64  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['add[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  8320        ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_5[0][0]',
#                                 8)                                'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['add_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  33024       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['add_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  131584      ['max_pooling2d_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['add_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 1024  525312      ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 16, 16, 1024  0           ['batch_normalization_14[0][0]',
#                                 )                                 'batch_normalization_13[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 512)  524800      ['activation_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 512)  262656      ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2359808    ['conv2d_17[0][0]']
#  ose)
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 512)  1049088     ['activation_7[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 512)  0           ['add_5[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 1)    513         ['activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 1)    0           ['conv2d_18[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1)    0           ['activation_12[0][0]']
#
#  lambda (Lambda)                (None, 32, 32, 512)  0           ['up_sampling2d[0][0]']
#
#  multiply (Multiply)            (None, 32, 32, 512)  0           ['lambda[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024  0          ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_19[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 32, 32, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 512)  786944      ['concatenate[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 512)  0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 512)  0           ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 256)  131328      ['activation_14[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  590080     ['conv2d_25[0][0]']
#  spose)
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 256)  262400      ['activation_5[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 256)  0           ['add_7[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 1)    257         ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 1)    0           ['conv2d_26[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_17[0][0]']
#
#  lambda_1 (Lambda)              (None, 64, 64, 256)  0           ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 256)  0           ['lambda_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 256)  65792       ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 512)  0          ['activation_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_3[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 256)  196864      ['concatenate_1[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_19 (Activation)     (None, 64, 64, 256)  0           ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 128)  32896       ['activation_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_20[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  147584     ['conv2d_33[0][0]']
#  spose)
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 128)  65664       ['activation_3[0][0]']
#
#  add_9 (Add)                    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 128)  0           ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 1)    129         ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 64, 64, 1)    0           ['conv2d_34[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_22[0][0]']
#
#  lambda_2 (Lambda)              (None, 128, 128, 12  0           ['up_sampling2d_4[0][0]']
#                                 8)
#
#  multiply_2 (Multiply)          (None, 128, 128, 12  0           ['lambda_2[0][0]',
#                                 8)                                'activation_3[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 12  16512       ['multiply_2[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_19[0][0]']
#                                 6)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_5[0][0]',
#                                 4)                                'batch_normalization_26[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 12  512        ['conv2d_36[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_27[0][0]']
#                                 8)
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 12  49280       ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 12  147584      ['activation_23[0][0]']
#                                 8)
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 12  512        ['conv2d_38[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 12  512        ['conv2d_37[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, 128, 128, 12  0           ['batch_normalization_29[0][0]',
#                                 8)                                'batch_normalization_28[0][0]']
#  activation_24 (Activation)     (None, 128, 128, 12  0           ['add_10[0][0]']
#                                 8)
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 64  8256        ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 64  4160        ['activation_25[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['conv2d_41[0][0]']
#  spose)                         )
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 64  16448       ['activation_1[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_40[0][0]']
#
#  activation_26 (Activation)     (None, 128, 128, 64  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 1)  65          ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 128, 128, 1)  0           ['conv2d_42[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_27[0][0]']
#
#  lambda_3 (Lambda)              (None, 256, 256, 64  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 256, 256, 64  0           ['lambda_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 64  4160        ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 12  0          ['activation_24[0][0]']
#                                 8)
#
#  batch_normalization_31 (BatchN  (None, 256, 256, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_7[0][0]',
#                                 2)                                'batch_normalization_31[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 64  12352       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 64  36928       ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 64  256        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 64  256        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 256, 256, 64  0           ['batch_normalization_34[0][0]',
#                                 )                                 'batch_normalization_33[0][0]']
#
#  activation_29 (Activation)     (None, 256, 256, 64  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 1)  65          ['activation_29[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 1)  4          ['conv2d_47[0][0]']
#  ormalization)
#  activation_30 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 39,090,377
# Trainable params: 39,068,871
# Non-trainable params: 21,506
# __________________________________________________________________________________________________
# /home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# None
# Epoch 1/150
# 2023-03-07 17:52:22.233318: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 23/23 [==============================] - 24s 484ms/step - loss: 0.1212 - accuracy: 0.8147 - jacard_coef: 0.3542 - val_loss: 4.1803 - val_accuracy: 0.7406 - val_jacard_coef: 1.3103e-05
# Epoch 2/150
# 23/23 [==============================] - 6s 269ms/step - loss: 0.0807 - accuracy: 0.8753 - jacard_coef: 0.3865 - val_loss: 4.1803 - val_accuracy: 0.7406 - val_jacard_coef: 1.3103e-05
# Epoch 3/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0710 - accuracy: 0.8909 - jacard_coef: 0.4039 - val_loss: 1.5899 - val_accuracy: 0.7458 - val_jacard_coef: 0.0680
# Epoch 4/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0677 - accuracy: 0.8961 - jacard_coef: 0.4152 - val_loss: 1.2298 - val_accuracy: 0.2444 - val_jacard_coef: 0.1959
# Epoch 5/150
# 23/23 [==============================] - 6s 267ms/step - loss: 0.0649 - accuracy: 0.9032 - jacard_coef: 0.4237 - val_loss: 1.9036 - val_accuracy: 0.2630 - val_jacard_coef: 0.2399
# Epoch 6/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0613 - accuracy: 0.9113 - jacard_coef: 0.4365 - val_loss: 2.7059 - val_accuracy: 0.2598 - val_jacard_coef: 0.2386
# Epoch 7/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0599 - accuracy: 0.9116 - jacard_coef: 0.4418 - val_loss: 1.5359 - val_accuracy: 0.3885 - val_jacard_coef: 0.2271
# Epoch 8/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0558 - accuracy: 0.9205 - jacard_coef: 0.4518 - val_loss: 1.2666 - val_accuracy: 0.3722 - val_jacard_coef: 0.2532
# Epoch 9/150
# 23/23 [==============================] - 6s 268ms/step - loss: 0.0555 - accuracy: 0.9186 - jacard_coef: 0.4578 - val_loss: 1.1147 - val_accuracy: 0.4018 - val_jacard_coef: 0.2521
# Epoch 10/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0526 - accuracy: 0.9237 - jacard_coef: 0.4669 - val_loss: 1.3676 - val_accuracy: 0.3339 - val_jacard_coef: 0.2545
# Epoch 11/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0521 - accuracy: 0.9232 - jacard_coef: 0.4731 - val_loss: 1.4587 - val_accuracy: 0.3287 - val_jacard_coef: 0.2562
# Epoch 12/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0497 - accuracy: 0.9267 - jacard_coef: 0.4810 - val_loss: 1.4903 - val_accuracy: 0.2781 - val_jacard_coef: 0.2501
# Epoch 13/150
# 23/23 [==============================] - 6s 267ms/step - loss: 0.0519 - accuracy: 0.9245 - jacard_coef: 0.4823 - val_loss: 1.7022 - val_accuracy: 0.2752 - val_jacard_coef: 0.2554
# Epoch 14/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0482 - accuracy: 0.9282 - jacard_coef: 0.4900 - val_loss: 1.7072 - val_accuracy: 0.2932 - val_jacard_coef: 0.2531
# Epoch 15/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0468 - accuracy: 0.9301 - jacard_coef: 0.4951 - val_loss: 0.7099 - val_accuracy: 0.5456 - val_jacard_coef: 0.3225
# Epoch 16/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0441 - accuracy: 0.9342 - jacard_coef: 0.5043 - val_loss: 0.6448 - val_accuracy: 0.4616 - val_jacard_coef: 0.3046
# Epoch 17/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0423 - accuracy: 0.9358 - jacard_coef: 0.5111 - val_loss: 0.9065 - val_accuracy: 0.3437 - val_jacard_coef: 0.2810
# Epoch 18/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0451 - accuracy: 0.9320 - jacard_coef: 0.5097 - val_loss: 0.3570 - val_accuracy: 0.5336 - val_jacard_coef: 0.3286
# Epoch 19/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0434 - accuracy: 0.9346 - jacard_coef: 0.5190 - val_loss: 0.3775 - val_accuracy: 0.4983 - val_jacard_coef: 0.3195
# Epoch 20/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0443 - accuracy: 0.9347 - jacard_coef: 0.5184 - val_loss: 0.2497 - val_accuracy: 0.6242 - val_jacard_coef: 0.3346
# Epoch 21/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0455 - accuracy: 0.9332 - jacard_coef: 0.5155 - val_loss: 0.3437 - val_accuracy: 0.6604 - val_jacard_coef: 0.3645
# Epoch 22/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0382 - accuracy: 0.9440 - jacard_coef: 0.5323 - val_loss: 0.1878 - val_accuracy: 0.7492 - val_jacard_coef: 0.3879
# Epoch 23/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0342 - accuracy: 0.9485 - jacard_coef: 0.5470 - val_loss: 0.1091 - val_accuracy: 0.8556 - val_jacard_coef: 0.4187
# Epoch 24/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0345 - accuracy: 0.9462 - jacard_coef: 0.5538 - val_loss: 0.0891 - val_accuracy: 0.8801 - val_jacard_coef: 0.4088
# Epoch 25/150
# 23/23 [==============================] - 6s 267ms/step - loss: 0.0361 - accuracy: 0.9422 - jacard_coef: 0.5528 - val_loss: 0.1238 - val_accuracy: 0.8133 - val_jacard_coef: 0.3860
# Epoch 26/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0326 - accuracy: 0.9512 - jacard_coef: 0.5619 - val_loss: 0.0851 - val_accuracy: 0.8806 - val_jacard_coef: 0.4261
# Epoch 27/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0325 - accuracy: 0.9506 - jacard_coef: 0.5670 - val_loss: 0.0949 - val_accuracy: 0.8507 - val_jacard_coef: 0.3900
# Epoch 28/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0331 - accuracy: 0.9493 - jacard_coef: 0.5689 - val_loss: 0.0574 - val_accuracy: 0.9202 - val_jacard_coef: 0.4655
# Epoch 29/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0314 - accuracy: 0.9508 - jacard_coef: 0.5770 - val_loss: 0.0594 - val_accuracy: 0.9344 - val_jacard_coef: 0.4377
# Epoch 30/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0305 - accuracy: 0.9533 - jacard_coef: 0.5812 - val_loss: 0.2553 - val_accuracy: 0.6422 - val_jacard_coef: 0.3340
# ...
# Epoch 69/150
# 23/23 [==============================] - 6s 268ms/step - loss: 0.0135 - accuracy: 0.9768 - jacard_coef: 0.7138 - val_loss: 0.0793 - val_accuracy: 0.9192 - val_jacard_coef: 0.5595
# Epoch 70/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0161 - accuracy: 0.9739 - jacard_coef: 0.7115 - val_loss: 0.0504 - val_accuracy: 0.9420 - val_jacard_coef: 0.6028
# Epoch 71/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0142 - accuracy: 0.9759 - jacard_coef: 0.7076 - val_loss: 0.0655 - val_accuracy: 0.9324 - val_jacard_coef: 0.5902
# Epoch 72/150
# 23/23 [==============================] - 6s 268ms/step - loss: 0.0146 - accuracy: 0.9752 - jacard_coef: 0.7195 - val_loss: 0.0730 - val_accuracy: 0.9284 - val_jacard_coef: 0.5864
# Epoch 73/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0172 - accuracy: 0.9704 - jacard_coef: 0.7037 - val_loss: 0.0597 - val_accuracy: 0.9281 - val_jacard_coef: 0.5428
# Epoch 74/150
# 23/23 [==============================] - 6s 268ms/step - loss: 0.0168 - accuracy: 0.9712 - jacard_coef: 0.7042 - val_loss: 0.0798 - val_accuracy: 0.9355 - val_jacard_coef: 0.5818
# Epoch 75/150
# 23/23 [==============================] - 6s 267ms/step - loss: 0.0165 - accuracy: 0.9721 - jacard_coef: 0.7103 - val_loss: 0.1355 - val_accuracy: 0.8912 - val_jacard_coef: 0.5475
# Epoch 76/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0142 - accuracy: 0.9760 - jacard_coef: 0.7141 - val_loss: 0.0774 - val_accuracy: 0.9264 - val_jacard_coef: 0.5938
# Epoch 77/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0117 - accuracy: 0.9793 - jacard_coef: 0.7344 - val_loss: 0.0625 - val_accuracy: 0.9380 - val_jacard_coef: 0.5821
# Epoch 78/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0111 - accuracy: 0.9800 - jacard_coef: 0.7409 - val_loss: 0.0761 - val_accuracy: 0.9310 - val_jacard_coef: 0.5837
# Epoch 79/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0111 - accuracy: 0.9802 - jacard_coef: 0.7378 - val_loss: 0.0787 - val_accuracy: 0.9260 - val_jacard_coef: 0.5702
# Epoch 80/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0113 - accuracy: 0.9799 - jacard_coef: 0.7446 - val_loss: 0.1120 - val_accuracy: 0.8804 - val_jacard_coef: 0.5405
# Epoch 81/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0127 - accuracy: 0.9779 - jacard_coef: 0.7326 - val_loss: 0.0765 - val_accuracy: 0.9303 - val_jacard_coef: 0.5890
# Epoch 82/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0120 - accuracy: 0.9791 - jacard_coef: 0.7387 - val_loss: 0.0781 - val_accuracy: 0.9380 - val_jacard_coef: 0.6184
# Epoch 83/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0117 - accuracy: 0.9793 - jacard_coef: 0.7411 - val_loss: 0.0811 - val_accuracy: 0.9272 - val_jacard_coef: 0.5781
# Epoch 84/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0111 - accuracy: 0.9803 - jacard_coef: 0.7479 - val_loss: 0.0751 - val_accuracy: 0.9324 - val_jacard_coef: 0.6061
# Epoch 85/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0111 - accuracy: 0.9801 - jacard_coef: 0.7471 - val_loss: 0.0739 - val_accuracy: 0.9393 - val_jacard_coef: 0.6143
# Epoch 86/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0102 - accuracy: 0.9816 - jacard_coef: 0.7568 - val_loss: 0.0816 - val_accuracy: 0.9305 - val_jacard_coef: 0.6051
# Epoch 87/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0099 - accuracy: 0.9818 - jacard_coef: 0.7571 - val_loss: 0.0897 - val_accuracy: 0.9243 - val_jacard_coef: 0.6075
# Epoch 88/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0095 - accuracy: 0.9827 - jacard_coef: 0.7608 - val_loss: 0.0811 - val_accuracy: 0.9311 - val_jacard_coef: 0.6092
# Epoch 89/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0096 - accuracy: 0.9823 - jacard_coef: 0.7639 - val_loss: 0.0745 - val_accuracy: 0.9391 - val_jacard_coef: 0.5990
# Epoch 90/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0102 - accuracy: 0.9815 - jacard_coef: 0.7594 - val_loss: 0.0789 - val_accuracy: 0.9324 - val_jacard_coef: 0.5997
# Epoch 91/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0114 - accuracy: 0.9799 - jacard_coef: 0.7553 - val_loss: 0.0777 - val_accuracy: 0.9329 - val_jacard_coef: 0.6327
# Epoch 92/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0122 - accuracy: 0.9788 - jacard_coef: 0.7476 - val_loss: 0.0725 - val_accuracy: 0.9308 - val_jacard_coef: 0.6366
# Epoch 93/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0163 - accuracy: 0.9718 - jacard_coef: 0.7357 - val_loss: 0.0873 - val_accuracy: 0.9186 - val_jacard_coef: 0.5961
# Epoch 94/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0147 - accuracy: 0.9753 - jacard_coef: 0.7289 - val_loss: 0.0830 - val_accuracy: 0.9301 - val_jacard_coef: 0.6148
# Epoch 95/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0134 - accuracy: 0.9764 - jacard_coef: 0.7434 - val_loss: 0.1098 - val_accuracy: 0.9184 - val_jacard_coef: 0.5828
# Epoch 96/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0154 - accuracy: 0.9742 - jacard_coef: 0.7300 - val_loss: 0.1093 - val_accuracy: 0.9018 - val_jacard_coef: 0.6070
# Epoch 97/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0245 - accuracy: 0.9617 - jacard_coef: 0.6874 - val_loss: 0.4513 - val_accuracy: 0.7551 - val_jacard_coef: 0.4667
# Epoch 98/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0228 - accuracy: 0.9632 - jacard_coef: 0.6786 - val_loss: 0.0977 - val_accuracy: 0.9321 - val_jacard_coef: 0.6269
# Epoch 99/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0247 - accuracy: 0.9593 - jacard_coef: 0.6757 - val_loss: 0.1020 - val_accuracy: 0.9124 - val_jacard_coef: 0.5575
# Epoch 100/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0283 - accuracy: 0.9573 - jacard_coef: 0.6554 - val_loss: 0.2255 - val_accuracy: 0.8311 - val_jacard_coef: 0.5700
# Epoch 101/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0267 - accuracy: 0.9576 - jacard_coef: 0.6561 - val_loss: 1.3402 - val_accuracy: 0.6007 - val_jacard_coef: 0.3697
# Epoch 102/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0218 - accuracy: 0.9659 - jacard_coef: 0.6798 - val_loss: 0.2115 - val_accuracy: 0.8450 - val_jacard_coef: 0.5065
# Epoch 103/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0188 - accuracy: 0.9706 - jacard_coef: 0.6933 - val_loss: 0.1457 - val_accuracy: 0.8564 - val_jacard_coef: 0.5504
# Epoch 104/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0146 - accuracy: 0.9744 - jacard_coef: 0.7253 - val_loss: 0.0979 - val_accuracy: 0.9078 - val_jacard_coef: 0.5791
# Epoch 105/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0126 - accuracy: 0.9780 - jacard_coef: 0.7341 - val_loss: 0.0869 - val_accuracy: 0.9252 - val_jacard_coef: 0.5782
# Epoch 106/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0110 - accuracy: 0.9805 - jacard_coef: 0.7495 - val_loss: 0.0615 - val_accuracy: 0.9441 - val_jacard_coef: 0.6200
# Epoch 107/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0105 - accuracy: 0.9810 - jacard_coef: 0.7543 - val_loss: 0.0711 - val_accuracy: 0.9383 - val_jacard_coef: 0.6147
# Epoch 108/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0097 - accuracy: 0.9819 - jacard_coef: 0.7641 - val_loss: 0.0809 - val_accuracy: 0.9326 - val_jacard_coef: 0.6139
# Epoch 109/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0093 - accuracy: 0.9826 - jacard_coef: 0.7630 - val_loss: 0.0744 - val_accuracy: 0.9293 - val_jacard_coef: 0.5832
# Epoch 110/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0092 - accuracy: 0.9829 - jacard_coef: 0.7714 - val_loss: 0.0794 - val_accuracy: 0.9178 - val_jacard_coef: 0.5507
# Epoch 111/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0091 - accuracy: 0.9831 - jacard_coef: 0.7696 - val_loss: 0.0904 - val_accuracy: 0.9015 - val_jacard_coef: 0.5261
# Epoch 112/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0096 - accuracy: 0.9823 - jacard_coef: 0.7705 - val_loss: 0.0901 - val_accuracy: 0.9067 - val_jacard_coef: 0.5422
# Epoch 113/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0092 - accuracy: 0.9829 - jacard_coef: 0.7728 - val_loss: 0.0727 - val_accuracy: 0.9166 - val_jacard_coef: 0.5623
# Epoch 114/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0097 - accuracy: 0.9820 - jacard_coef: 0.7701 - val_loss: 0.0548 - val_accuracy: 0.9357 - val_jacard_coef: 0.6122
# Epoch 115/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0108 - accuracy: 0.9804 - jacard_coef: 0.7739 - val_loss: 0.0598 - val_accuracy: 0.9314 - val_jacard_coef: 0.6272
# Epoch 116/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0163 - accuracy: 0.9728 - jacard_coef: 0.7265 - val_loss: 0.0712 - val_accuracy: 0.9399 - val_jacard_coef: 0.6063
# Epoch 117/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0146 - accuracy: 0.9744 - jacard_coef: 0.7343 - val_loss: 0.1654 - val_accuracy: 0.8909 - val_jacard_coef: 0.5890
# Epoch 118/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0126 - accuracy: 0.9786 - jacard_coef: 0.7358 - val_loss: 0.1322 - val_accuracy: 0.8977 - val_jacard_coef: 0.5905
# Epoch 119/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0105 - accuracy: 0.9809 - jacard_coef: 0.7673 - val_loss: 0.1332 - val_accuracy: 0.8929 - val_jacard_coef: 0.5825
# Epoch 120/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0092 - accuracy: 0.9827 - jacard_coef: 0.7736 - val_loss: 0.1463 - val_accuracy: 0.8939 - val_jacard_coef: 0.5899
# Epoch 121/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0085 - accuracy: 0.9838 - jacard_coef: 0.7777 - val_loss: 0.1031 - val_accuracy: 0.9118 - val_jacard_coef: 0.6131
# Epoch 122/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0079 - accuracy: 0.9847 - jacard_coef: 0.7889 - val_loss: 0.0970 - val_accuracy: 0.9166 - val_jacard_coef: 0.6145
# Epoch 123/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0088 - accuracy: 0.9833 - jacard_coef: 0.7894 - val_loss: 0.1100 - val_accuracy: 0.9140 - val_jacard_coef: 0.6276
# Epoch 124/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0085 - accuracy: 0.9836 - jacard_coef: 0.7866 - val_loss: 0.0987 - val_accuracy: 0.9195 - val_jacard_coef: 0.6325
# Epoch 125/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0097 - accuracy: 0.9820 - jacard_coef: 0.7880 - val_loss: 0.0788 - val_accuracy: 0.9320 - val_jacard_coef: 0.6535
# Epoch 126/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0106 - accuracy: 0.9805 - jacard_coef: 0.7849 - val_loss: 0.1057 - val_accuracy: 0.9166 - val_jacard_coef: 0.6432
# Epoch 127/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0106 - accuracy: 0.9804 - jacard_coef: 0.7761 - val_loss: 0.2129 - val_accuracy: 0.8646 - val_jacard_coef: 0.5622
# Epoch 128/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0097 - accuracy: 0.9818 - jacard_coef: 0.7796 - val_loss: 0.1001 - val_accuracy: 0.9300 - val_jacard_coef: 0.6257
# Epoch 129/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0108 - accuracy: 0.9808 - jacard_coef: 0.7800 - val_loss: 0.1181 - val_accuracy: 0.9268 - val_jacard_coef: 0.6461
# Epoch 130/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0116 - accuracy: 0.9798 - jacard_coef: 0.7695 - val_loss: 0.0834 - val_accuracy: 0.9371 - val_jacard_coef: 0.6608
# Epoch 131/150
# 23/23 [==============================] - 6s 265ms/step - loss: 0.0110 - accuracy: 0.9807 - jacard_coef: 0.7673 - val_loss: 0.1066 - val_accuracy: 0.9194 - val_jacard_coef: 0.6537
# Epoch 132/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0117 - accuracy: 0.9802 - jacard_coef: 0.7681 - val_loss: 0.0939 - val_accuracy: 0.9324 - val_jacard_coef: 0.7018
# Epoch 133/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0093 - accuracy: 0.9827 - jacard_coef: 0.7717 - val_loss: 0.1145 - val_accuracy: 0.9241 - val_jacard_coef: 0.6567
# Epoch 134/150
# 23/23 [==============================] - 6s 266ms/step - loss: 0.0095 - accuracy: 0.9822 - jacard_coef: 0.7832 - val_loss: 0.1079 - val_accuracy: 0.9370 - val_jacard_coef: 0.6698
# Epoch 135/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0094 - accuracy: 0.9820 - jacard_coef: 0.7827 - val_loss: 0.1259 - val_accuracy: 0.9387 - val_jacard_coef: 0.6313
# Epoch 136/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0105 - accuracy: 0.9807 - jacard_coef: 0.7806 - val_loss: 0.1248 - val_accuracy: 0.9338 - val_jacard_coef: 0.6166
# Epoch 137/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0113 - accuracy: 0.9799 - jacard_coef: 0.7772 - val_loss: 0.1257 - val_accuracy: 0.9303 - val_jacard_coef: 0.6163
# Epoch 138/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0138 - accuracy: 0.9775 - jacard_coef: 0.7593 - val_loss: 0.1382 - val_accuracy: 0.8972 - val_jacard_coef: 0.5552
# Epoch 139/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0135 - accuracy: 0.9774 - jacard_coef: 0.7436 - val_loss: 0.1287 - val_accuracy: 0.9361 - val_jacard_coef: 0.6059
# Epoch 140/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0107 - accuracy: 0.9808 - jacard_coef: 0.7732 - val_loss: 0.1678 - val_accuracy: 0.8850 - val_jacard_coef: 0.5415
# Epoch 141/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0097 - accuracy: 0.9820 - jacard_coef: 0.7771 - val_loss: 0.0766 - val_accuracy: 0.9366 - val_jacard_coef: 0.6268
# Epoch 142/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0089 - accuracy: 0.9830 - jacard_coef: 0.7887 - val_loss: 0.0748 - val_accuracy: 0.9398 - val_jacard_coef: 0.6451
# Epoch 143/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0088 - accuracy: 0.9832 - jacard_coef: 0.7849 - val_loss: 0.0873 - val_accuracy: 0.9306 - val_jacard_coef: 0.6443
# Epoch 144/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0075 - accuracy: 0.9853 - jacard_coef: 0.7989 - val_loss: 0.0815 - val_accuracy: 0.9302 - val_jacard_coef: 0.6507
# Epoch 145/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0079 - accuracy: 0.9844 - jacard_coef: 0.7973 - val_loss: 0.1001 - val_accuracy: 0.9128 - val_jacard_coef: 0.6115
# Epoch 146/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0074 - accuracy: 0.9856 - jacard_coef: 0.8004 - val_loss: 0.1002 - val_accuracy: 0.9119 - val_jacard_coef: 0.6067
# Epoch 147/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0077 - accuracy: 0.9846 - jacard_coef: 0.8036 - val_loss: 0.0893 - val_accuracy: 0.9180 - val_jacard_coef: 0.6266
# Epoch 148/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0083 - accuracy: 0.9842 - jacard_coef: 0.8078 - val_loss: 0.1049 - val_accuracy: 0.9192 - val_jacard_coef: 0.6527
# Epoch 149/150
# 23/23 [==============================] - 6s 264ms/step - loss: 0.0091 - accuracy: 0.9826 - jacard_coef: 0.7991 - val_loss: 0.0966 - val_accuracy: 0.9215 - val_jacard_coef: 0.6418
# Epoch 150/150
# 23/23 [==============================] - 6s 263ms/step - loss: 0.0090 - accuracy: 0.9828 - jacard_coef: 0.8014 - val_loss: 0.0848 - val_accuracy: 0.9419 - val_jacard_coef: 0.6863
# Attention ResUnet execution time is:  0:15:31.707686

# %%
import pandas as pd    
att_res_unet_history_df = pd.DataFrame(att_res_unet_history.history) 

with open('custom_code_att_res_unet_history_df.csv', mode='w') as f:
    att_res_unet_history_df.to_csv(f)

# %%
history = att_res_unet_history

#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['jacard_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_jacard_coef']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Jacard')
plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
plt.title('Training and validation Jacard')
plt.xlabel('Epochs')
plt.ylabel('Jacard')
plt.legend()
plt.show()

# %%
model = att_res_unet_model
model_path = "skin_AttResUnet_50epochs_B_focal.hdf5"
model = tf.keras.models.load_model(model_path, compile=False)

# %%
import random
test_img_number = random.randint(0, X_test.shape[0]-1)
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]

test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.97712815

# %%
import pandas as pd

IoU_values = []
for img in range(0, X_test.shape[0]):
    temp_img = X_test[img]
    ground_truth=y_test[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 0.84919274
# 1/1 [==============================] - 0s 79ms/step
# 0.9430684
# 1/1 [==============================] - 0s 88ms/step
# 0.9519496
# 1/1 [==============================] - 0s 127ms/step
# 0.5120618
# 1/1 [==============================] - 0s 67ms/step
# 0.89878607
# 1/1 [==============================] - 0s 145ms/step
# 0.8031287
# 1/1 [==============================] - 0s 96ms/step
# 0.91078234
# 1/1 [==============================] - 0s 134ms/step
# 0.49575895
# 1/1 [==============================] - 0s 86ms/step
# 0.9408597
# 1/1 [==============================] - 0s 61ms/step
# 0.95739806
# 1/1 [==============================] - 0s 88ms/step
# 0.95057935
# 1/1 [==============================] - 0s 103ms/step
# 0.9167057
# 1/1 [==============================] - 0s 122ms/step
# 0.8982712
# 1/1 [==============================] - 0s 110ms/step
# 0.94884944
# 1/1 [==============================] - 0s 102ms/step
# 0.8944236
# 1/1 [==============================] - 0s 119ms/step
# 0.87394595
# 1/1 [==============================] - 0s 170ms/step
# 0.9323833
# 1/1 [==============================] - 0s 100ms/step
# 0.918378
# 1/1 [==============================] - 0s 106ms/step
# 0.9134395
# 1/1 [==============================] - 0s 127ms/step
# 0.9009718
# Mean IoU is:  [0.8705468]
